# %% [markdown]
# # Оптимизация выполнения кода, векторизация, Numba

# %% [markdown]
# __Автор задач: Блохин Н.В. (NVBlokhin@fa.ru)__
#
# Материалы:
# * Макрушин С.В. "Оптимизация выполнения кода, векторизация, Numba"
# * IPython Cookbook, Second Edition (2018), глава 4
# * https://ipython-books.github.io/43-profiling-your-code-line-by-line-with-line_profiler/
# * https://numba.pydata.org/numba-doc/latest/user/5minguide.html
# * https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types

# %% [markdown]
# ## Задачи для совместного разбора

# %%
# !pip install git+https://github.com/pyutils/line_profiler.git
# !pip install line_profiler
# !pip install --user numpy==1.20
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/pyutils/line_profiler.git
#   Cloning https://github.com/pyutils/line_profiler.git to /tmp/pip-req-build-cv6p_ub7
#   Running command git clone -q https://github.com/pyutils/line_profiler.git /tmp/pip-req-build-cv6p_ub7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: line-profiler
#   Building wheel for line-profiler (PEP 517) ... done
#   Created wheel for line-profiler: filename=line_profiler-4.0.2-cp38-cp38-linux_x86_64.whl size=460004 sha256=45b03b220377541eef3c8acb3225bb13881b42399d8049544dab40ce58d553c3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0jz0b9nb/wheels/d3/20/57/fccf8f1a95000db18d57f1c7b8d0b78d33020f82f50f7b26f6
# Successfully built line-profiler
# Installing collected packages: line-profiler
# Successfully installed line-profiler-4.0.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: line_profiler in /usr/local/lib/python3.8/dist-packages (4.0.2)

# %%
import numpy as np
import numba
from numba import njit

# %% [markdown]
# 1. Сгенерируйте массив `A` из `N=1млн` случайных целых чисел на отрезке от 0 до 1000. Пусть `B[i] = A[i] + 100`. Посчитайте среднее значение массива `B`.

# %% [markdown]
# 2. Напишите функцию, которая возвращает сумму всех чисел от 0 до x-1. Примените функцию к каждому элементу массива.

# %% [markdown]
# 3. Создайте таблицу 2млн строк и с 4 столбцами, заполненными случайными числами. Добавьте столбец `key`, которые содержит элементы из множества английских букв. Выберите из таблицы подмножество строк, для которых в столбце `key` указаны первые 5 английских букв.

# %%
# %load_ext line_profiler

# %%
import pandas as pd
import string

N = 2_000_000
df = pd.DataFrame(np.random.randn(N, 4), columns=[f"col{i}" for i in range(4)])
df["key"] = np.random.choice(list(string.ascii_letters.lower()), N, replace=True)
df.head(2)
# Out:
#        col0      col1      col2      col3 key
# 0  0.839492  0.807467  1.481977 -1.071109   h
# 1 -0.144447  0.068865  1.064956 -0.701123   w

# %% [markdown]
# ## Лабораторная работа 8

# %%
import numpy as np
import pandas as pd
from numba import jit, njit, guvectorize
import numba
from typing import Union
import re

# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %% [markdown]
# В файлах `recipes_sample.csv` и `reviews_sample.csv` (__ЛР 2__) находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца(ов) с индексами. Приведите столбцы к нужным типам.

# %% [markdown]
# ## Измерение времени выполнения кода

# %% [markdown]
# Назовем полным описанием рецепта строку, полученную путем конкатенации названия и описания рецепта через пробел. Удалите строки для рецептов, которые были добавлены не в 2010 году.
#
# Реализуйте несколько вариантов функции подсчета средней длины полного описания рецепта для рецептов, добавленных в 2010 году.

# %%
recipes = pd.read_csv('recipes_sample (1).csv', parse_dates = ['submitted'])
reviews = pd.read_csv('reviews_sample (1).csv')

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
# [30000 rows x 8 columns]

# %%
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0           370476       21752      57993  2003-05-01       5
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...                                                   ...
# 126691  This recipe was great! I made it last night. I...
# 126692  This recipe is outstanding. I followed the rec...
# 126693  Well, we were not a crowd but it was a fabulou...
# 126694  I have been a steak eater and dedicated BBQ gr...
# 126695  Wonderful and simple to prepare seasoning blen...
#
# [126696 rows x 6 columns]

# %%
recipes['submitted'] = pd.to_datetime(recipes.submitted)
new_recipes = recipes[recipes.submitted.dt.year == 2010]

# %%
new_recipes
# Out:
#                                                     name      id  minutes  \
# 52                                  just peachy  cobbler  437637       70
# 68                             the heat  spicy party mix  437219       95
# 81     iowa state fair  sweet dough caramel cinnamon ...  435816       80
# 104                         1 minute blueberries   cream  428566        2
# 146                                     2 2 2 diet mocha  416599        5
# ...                                                  ...     ...      ...
# 29897                             zoe s chicken tarragon  441211       40
# 29907                          zucchini and noodle slice  412518       60
# 29915                     zucchini bread   bread machine  409757      220
# 29926                             zucchini chip cupcakes  406686       35
# 29992  zucchini  courgette soup  good for weight watc...  415406       45
#
#        contributor_id  submitted  n_steps  \
# 52            1085867 2010-09-17     10.0
# 68            1682162 2010-09-13      NaN
# 81              17803 2010-08-24     29.0
# 104           1375473 2010-06-04      4.0
# 146            789314 2010-03-15      5.0
# ...               ...        ...      ...
# 29897           76559 2010-11-04     12.0
# 29907          423555 2010-02-10     21.0
# 29915          539686 2010-01-22      7.0
# 29926          628076 2010-01-04      9.0
# 29992          485109 2010-03-04      5.0
#
#                                              description  n_ingredients
# 52     all i can say is yummmmmm . . . a simple to ma...           10.0
# 68     a spicy chex mix that will really warm your gu...           11.0
# 81     this was the winning entry at the 2010 iowa st...            NaN
# 104    i was craving blueberry tonight but wanted non...            NaN
# 146    while trying to come up with a satisfying "sna...            7.0
# ...                                                  ...            ...
# 29897  from a good housekeeping at my hair salon.  ha...            9.0
# 29907  a yummy, tasty slice packed with vegies and ri...           13.0
# 29915  originally from a packet of red star yeast, th...            NaN
# 29926  this is a great tasting recipe to use up zucch...           14.0
# 29992  this is a favourite winter warmer. by british ...            NaN
#
# [1538 rows x 8 columns]

# %% [markdown]
# 1\.1 С использованием метода `DataFrame.iterrows` таблицы:
#
#     - функция принимает на вход таблицу, содержащую рецепты за 2010 год;
#
#     - нахождение полного описания рецепта осуществляется внутри цикла по `iterrows` для каждой строки по отдельности.

# %%
def get_mean_len_A(df):
    s = k = 0
    for i in df.iterrows():
        s += len(i[1][0]) + len(i[1][6]) + 1
        k += 1
    return s/k

# %%
get_mean_len_A(df)
# Out:
# 265.501300390117

# %% [markdown]
# 1\.2. С использованием метода `DataFrame.apply` таблицы:
#
#     - функция принимает на вход таблицу, содержащую рецепты за 2010 год;
#
#     - вызываете метод apply у таблицы, в качестве аргумента передаете функцию, которая возвращает полное описание для каждой строки;
#
#     - считаете среднюю длину описаний, вызвав соответствующий метод серии.

# %%
def get_mean_len_B(Data):
    sum_ = (df.apply(lambda x: x["name"] + x.description, axis=1).str.len())
    return  sum(sum_/len(df))

# %%
get_mean_len_B(new_recipes)
# Out:
# 264.5013003901173

# %%
def get_mean_len_B2(Data):
    return df.apply(lambda x: len(x['name']) + len(x.description), axis=1).mean()

# %%
get_mean_len_B2(df)
# Out:
# 264.501300390117

# %% [markdown]
# 1\.3. С использованием векторизованных методов серий `pd.Series`:
#
#     - функция принимает на вход таблицу, содержащую рецепты за 2010 год;
#
#     - при помощи векторизированных операций получаете столбец с полным описанием;
#
#     - при помощи векторизированных операций получаете длины полного описания;
#
#     - при помощи метода серий получаете среднюю длину полных описаний.

# %%
def get_mean_len_C(Data):
    return (df['name'] + df.description).str.len().mean()

# %%
get_mean_len_C(new_recipes)
# Out:
# 265.501300390117

# %% [markdown]
# 1.4 Проверьте, что результаты работы всех написанных функций корректны и совпадают. Измерьте выполнения всех написанных функций при помощи магических команд `time` и `timeit`.

# %%
# %time get_mean_len_A(new_recipes)
# Out:
# CPU times: user 78.1 ms, sys: 953 µs, total: 79.1 ms
# Wall time: 82.1 ms
# 265.501300390117

# %%
# %time get_mean_len_B(new_recipes)
# Out:
# CPU times: user 38.6 ms, sys: 0 ns, total: 38.6 ms
# Wall time: 46.2 ms
# 264.5013003901173

# %%
# %time get_mean_len_C(new_recipes)
# Out:
# CPU times: user 4.6 ms, sys: 0 ns, total: 4.6 ms
# Wall time: 4.52 ms
# 264.501300390117

# %% [markdown]
# ## Анализ пошагового выполнения кода

# %% [markdown]
# Вам предлагается воспользоваться функцией, которая собирает статистику о том, сколько отзывов содержат то или иное слово.

# %%
import re


def get_word_reviews_count(df):
    word_reviews = {}
    for _, row in df.dropna(subset=["review"]).iterrows():
        recipe_id, review = row["recipe_id"], row["review"]
        words = re.sub("[^A-Za-z\s]", "", review).split(" ")
        for word in words:
            if word not in word_reviews:
                word_reviews[word] = []
            word_reviews[word].append(recipe_id)

    word_reviews_count = {}
    for _, row in df.dropna(subset=["review"]).iterrows():
        review = row["review"]
        words = re.sub("[^A-Za-z\s]", "", review).split(" ")
        for word in words:
            word_reviews_count[word] = len(word_reviews[word])
    return word_reviews_count

# %% [markdown]
# 2.1 Найдите узкие места в коде, проанализировав код функции по шагам, используя профайлер. Сохраните результаты работы профайлера в отдельную текстовую ячейку. Выпишите (словами), что в имеющемся коде реализовано неоптимально.

# %% [markdown]
# 2.2  Оптимизируйте функцию и добейтесь значительного (как минимум, в 5 раз) прироста в скорости выполнения. Для демонстрации результата измерьте скорость выполнения оригинальной функции и функции, написанной вами.

# %%
def get_word_reviews_count_opt(df):
    word_reviews_count = {}
    for row in df['review'].dropna():
        #print(row)
        words = re.sub("[^A-Za-z\s]", "", row).split(" ")
        for word in words:
            word_reviews_count[word] = word_reviews_count.get(word,0)+1
    return word_reviews_count

# %%
# %time get_word_reviews_count(new_recipes)
# Out:
# CPU times: user 22.3 s, sys: 144 ms, total: 22.4 s
# Wall time: 23.3 s
# {'Last': 97,
#  'week': 1509,
#  'whole': 5782,
#  'sides': 458,
#  'of': 109239,
#  'frozen': 2943,
#  'salmon': 1032,
#  'fillet': 92,
#  'was': 89617,
#  'on': 36121,
#  'sale': 262,
#  'in': 62796,
#  'my': 44644,
#  'local': 572,
#  'supermarket': 95,
#  'so': 46848,
#  'I': 288243,
#  'bought': 1514,
#  'tons': 163,
#  'okay': 600,
#  'only': 14209,
#  '': 330966,
#  'but': 43035,
#  'total': 512,
#  'weight': 216,
#  'over': 9801,
#  'pounds': 291,
#  'This': 39555,
#  'recipe': 71751,
#  'is': 56519,
#  'perfect': 7807,
#  'for': 123162,
#  'even': 8074,
#  'though': 4942,
#  'it': 133219,
#  'calls': 525,
#  'steaks': 511,
#  'cut': 6848,
#  'up': 16178,
#  'the': 266530,
#  'into': 7085,
#  'individual': 314,
#  'portions': 214,
#  'and': 219215,
#  'followed': 4880,
#  'instructions': 1007,
#  'exactly': 4625,
#  'Im': 8330,
#  'one': 17615,
#  'those': 2419,
#  'food': 3498,
#  'combining': 78,
#  'diets': 45,
#  'left': 5064,
#  'out': 25697,
#  'white': 3690,
#  'wine': 1760,
#  'added': 22099,
#  'just': 25271,
#  'a': 166467,
#  'dash': 547,
#  'vinegar': 1946,
#  'instead': 11644,
#  'little': 16798,
#  'bit': 11153,
#  'not': 23840,
#  'enough': 5516,
#  'to': 132170,
#  'change': 4464,
#  'taste': 11290,
#  'dish': 9853,
#  'Super': 867,
#  'yummy': 5045,
#  'leftovers': 2318,
#  'lunch': 2501,
#  'today': 1915,
#  'lucky': 127,
#  'me': 10937,
#  'So': 4779,
#  'simple': 4911,
#  'tasty': 8112,
#  'used': 45538,
#  'yellow': 851,
#  'capsicum': 59,
#  'place': 2166,
#  'green': 4639,
#  'because': 11649,
#  'thats': 2027,
#  'what': 7676,
#  'had': 28047,
#  'hand': 3937,
#  'came': 5279,
#  'together': 5451,
#  'fast': 1387,
#  'Perfect': 1136,
#  'meal': 4348,
#  'if': 7448,
#  'you': 28143,
#  'dont': 7522,
#  'have': 35532,
#  'lot': 3905,
#  'time': 24744,
#  'Easy': 2302,
#  'healthy': 1854,
#  'Thanks': 32325,
#  'Stardustannie': 11,
#  'Made': 13439,
#  'PAC': 1827,
#  'Fall': 758,
#  'Very': 8891,
#  'nice': 9478,
#  'breakfast': 2266,
#  'HH': 7,
#  'easy': 21683,
#  'make': 37321,
#  'with': 59275,
#  'fresh': 8213,
#  'hot': 4172,
#  'coffe': 16,
#  'Instead': 908,
#  'toast': 703,
#  'served': 6550,
#  'by': 6670,
#  'Paula': 222,
#  'G': 44,
#  'that': 38949,
#  'made': 39363,
#  'earlier': 215,
#  'turned': 6379,
#  'great': 27326,
#  'will': 24097,
#  'be': 25514,
#  'regular': 3155,
#  'our': 6908,
#  'house': 2466,
#  'DH': 4114,
#  'loved': 13957,
#  'them': 25768,
#  'These': 8403,
#  'are': 15758,
#  'favorite': 3357,
#  'holidays': 340,
#  'children': 462,
#  'We': 12628,
#  'also': 15275,
#  'use': 17487,
#  'Rolo': 6,
#  'candies': 83,
#  'kisses': 84,
#  'Excellent': 2602,
#  'soup': 7150,
#  'The': 25845,
#  'tomato': 2427,
#  'flavor': 13426,
#  'this': 93873,
#  'freezer': 1329,
#  'tag': 1490,
#  'froze': 679,
#  'beautifully': 833,
#  'prepared': 1005,
#  'as': 35863,
#  'directed': 1353,
#  'then': 8692,
#  'allowed': 234,
#  'cool': 1160,
#  'container': 348,
#  'thawed': 283,
#  'fridge': 1463,
#  'reheated': 297,
#  'stovetop': 253,
#  'Worked': 253,
#  'perfectly': 1908,
#  'forgot': 1367,
#  'add': 13152,
#  'skim': 437,
#  'milk': 5487,
#  'still': 6783,
#  'tasted': 4443,
#  'pretty': 3762,
#  'good': 31181,
#  'Dancer': 72,
#  'dinner': 6102,
#  'excellent': 3167,
#  'finally': 543,
#  'found': 5203,
#  'tuna': 626,
#  'casserole': 1214,
#  'we': 13106,
#  'enjoy': 1480,
#  'thanks': 3937,
#  'When': 1641,
#  'snapped': 10,
#  'picture': 574,
#  'review': 1749,
#  'toasted': 837,
#  'pecans': 961,
#  'at': 15556,
#  'party': 1953,
#  'Prime': 23,
#  'Rib': 36,
#  'Ten': 16,
#  'stars': 3566,
#  'Lennie': 87,
#  'combination': 2276,
#  'flavors': 3266,
#  'reduce': 929,
#  'rice': 5454,
#  'cilantro': 1184,
#  'next': 10208,
#  'sharing': 11629,
#  'honKitten': 39,
#  'Oh': 1992,
#  'Bergy': 188,
#  'wonderful': 9253,
#  'cakes': 691,
#  'awesome': 2545,
#  'Fast': 158,
#  'put': 8603,
#  'get': 6853,
#  'fish': 1594,
#  'where': 997,
#  'live': 480,
#  'yuck': 26,
#  'am': 6321,
#  'tired': 165,
#  'trying': 1923,
#  'new': 2864,
#  'recipes': 4118,
#  'help': 918,
#  'lack': 181,
#  'quality': 492,
#  'But': 2905,
#  'problem': 1317,
#  'did': 18661,
#  'cloves': 1189,
#  'garlic': 8961,
#  'seasoned': 865,
#  'bread': 8116,
#  'crumbs': 1210,
#  'Smash': 3,
#  'Seasoning': 232,
#  'It': 19513,
#  'has': 4917,
#  'no': 6211,
#  'salt\r\nI': 6,
#  'tartar': 84,
#  'sauce': 16769,
#  'go': 4057,
#  '\r\nThank': 66,
#  'very': 26040,
#  'moist': 3831,
#  'cornbread': 529,
#  'two': 4806,
#  'days': 1168,
#  'later': 907,
#  'less': 3398,
#  'sugar': 9368,
#  'honey': 1834,
#  'farm': 84,
#  'butterand': 3,
#  'corn': 2728,
#  'about': 13225,
#  'ears': 59,
#  'Served': 1975,
#  'ribs': 1627,
#  'grill': 1288,
#  'Ive': 6503,
#  'been': 5841,
#  'making': 11171,
#  'past': 540,
#  'several': 1729,
#  'years': 2425,
#  'Its': 3661,
#  'always': 4249,
#  'extremely': 602,
#  'posting': 9924,
#  'generic': 34,
#  'sweetened': 261,
#  'condensed': 237,
#  'works': 893,
#  'well': 9879,
#  'tastes': 2832,
#  'costs': 20,
#  'usually': 1948,
#  'WalMart': 11,
#  'brand': 423,
#  'Exceptional': 15,
#  'delicious': 14634,
#  'really': 19695,
#  'liked': 5738,
#  'weekday': 73,
#  'leftover': 1936,
#  'looking': 3138,
#  'different': 4105,
#  'ways': 498,
#  'ground': 2519,
#  'beef': 3224,
#  'love': 9914,
#  'sandwich': 1316,
#  'alot': 596,
#  'sooo': 604,
#  'Lite': 33,
#  'brown': 3823,
#  'mustard': 1542,
#  'horse': 6,
#  'relish': 242,
#  'some': 21057,
#  'olives': 925,
#  'ons': 2,
#  'Next': 3516,
#  'balsamic': 529,
#  'dressingit': 3,
#  'mind': 483,
#  'cbreezie': 2,
#  'affordable': 33,
#  'addicting': 105,
#  'Our': 366,
#  'household': 157,
#  'Blessings': 8,
#  'chef': 414,
#  'never': 5019,
#  'apple': 1610,
#  'orange': 1778,
#  'juice': 3949,
#  'makes': 3372,
#  'all': 18010,
#  'difference': 1215,
#  'texture': 3618,
#  'wonderful\r\nThank': 4,
#  'You': 2450,
#  'were': 21189,
#  'grated': 977,
#  'cheddar': 1776,
#  'cheese': 11944,
#  'top': 6408,
#  'minutes': 8327,
#  'before': 8099,
#  'they': 17014,
#  'done': 2549,
#  'seasoning': 2861,
#  'best': 5295,
#  'pizza': 1250,
#  'dough': 3393,
#  'Other': 576,
#  'tried': 4747,
#  'machine': 760,
#  'way': 8213,
#  'too': 16024,
#  'sticky': 595,
#  'Leaving': 11,
#  'msg': 32,
#  'fine': 2128,
#  'divide': 63,
#  'half': 9003,
#  'knead': 106,
#  'floured': 90,
#  'surface': 96,
#  'few': 4934,
#  'times': 3323,
#  'stretch': 81,
#  'cirle': 1,
#  'like': 20964,
#  'bake': 2099,
#  'castiron': 25,
#  'skillet': 650,
#  'brush': 168,
#  'pan': 5518,
#  'olive': 2084,
#  'oil': 5607,
#  'sprinkle': 644,
#  'crust': 2487,
#  'lowest': 29,
#  'rack': 362,
#  'oven': 5135,
#  'saw': 752,
#  'Giada': 9,
#  'Today': 120,
#  'show': 212,
#  'last': 4600,
#  'month': 422,
#  'wanted': 2838,
#  'compare': 147,
#  'family': 8392,
#  'being': 1865,
#  'Marsala': 29,
#  'dry': 3015,
#  'red': 4608,
#  'chickenturkey': 4,
#  'sausage': 1639,
#  'cutting': 584,
#  'sausages': 149,
#  'finishing': 132,
#  'cooking': 5412,
#  'stove': 768,
#  'My': 14460,
#  'traditionally': 29,
#  'serves': 178,
#  'peppers': 2253,
#  'polentathis': 1,
#  'compared': 132,
#  'probably': 2736,
#  'calories': 679,
#  'heats': 11,
#  'kitchen': 800,
#  'summertime': 75,
#  'meatloaf': 605,
#  'took': 3867,
#  'reviewers': 889,
#  'suggestion': 619,
#  'another': 4903,
#  'crock': 1080,
#  'pot': 2565,
#  'sweet': 6989,
#  'tangy': 411,
#  'wonder': 276,
#  'addition': 2228,
#  'again': 21144,
#  'deliciously': 99,
#  'can': 9814,
#  'literally': 162,
#  'thrown': 106,
#  'soups': 338,
#  'i': 7877,
#  'ever': 4458,
#  'uncomplicated': 11,
#  'from': 12975,
#  'appealed': 21,
#  'simplicity': 213,
#  'quick': 4909,
#  'could': 6482,
#  'both': 2894,
#  'anything': 1780,
#  'see': 2343,
#  'more': 18338,
#  'substance': 25,
#  'nothing': 777,
#  'thankfully': 29,
#  'rustic': 49,
#  'roasted': 1303,
#  'balance': 454,
#  'other': 7203,
#  'ingredients': 6112,
#  'paul': 2,
#  'newman': 1,
#  'marinara': 133,
#  'cup': 8138,
#  'let': 2922,
#  'simmer': 447,
#  'would': 16822,
#  'definitly': 60,
#  'much': 15206,
#  'plus': 925,
#  'tea': 847,
#  'aroma': 369,
#  'steeping': 11,
#  'five': 713,
#  'large': 2229,
#  'glass': 659,
#  'ice': 1597,
#  'enjoyed': 7164,
#  'Good': 1692,
#  'marinade': 1474,
#  'Jack': 194,
#  'Daniels': 34,
#  'except': 2181,
#  'didnt': 16680,
#  'marinate': 390,
#  'quite': 3840,
#  'long': 2412,
#  'hours': 3234,
#  'grilled': 1304,
#  'counter': 188,
#  'everyone': 2770,
#  'Even': 1384,
#  'who': 3207,
#  'doesnt': 2209,
#  'dressed': 67,
#  'said': 3953,
#  'Almost': 109,
#  'teriyaki': 103,
#  'baked': 4392,
#  'potato': 2016,
#  'asparagus': 649,
#  'Fantastic': 799,
#  'earning': 2,
#  'raves': 144,
#  'table': 770,
#  'homegirl': 12,
#  'comforting': 228,
#  'lowsodium': 77,
#  'lowfat': 491,
#  'chicken': 13602,
#  'stock': 1189,
#  'butter': 7721,
#  'dried': 2404,
#  'parsley': 1216,
#  'do': 7567,
#  'than': 10347,
#  'an': 10577,
#  'hour': 1772,
#  'Me': 82,
#  'course': 892,
#  'Breezermom': 9,
#  'Market': 208,
#  'game': 1202,
#  'Will': 3440,
#  'kids': 3696,
#  'weekend': 746,
#  'your': 6423,
#  'cookies': 2942,
#  'already': 1785,
#  'Triple': 18,
#  'Chocolates': 2,
#  'Were': 143,
#  'addicted': 91,
#  'jam': 631,
#  'its': 7254,
#  'tend': 205,
#  'vinegarphobic': 1,
#  'adore': 109,
#  'black': 1664,
#  'pepper': 6580,
#  'increase': 510,
#  'Also': 3063,
#  'once': 1754,
#  'strawberries': 823,
#  'cook': 4881,
#  'down': 3702,
#  'masher': 53,
#  'break': 208,
#  'consistency': 980,
#  'kick': 1065,
#  'fun': 1140,
#  'English': 160,
#  'muffins': 1921,
#  'peanut': 1369,
#  'jelly': 403,
#  'sandwiches': 859,
#  'wheat': 1923,
#  'wish': 849,
#  'canning': 170,
#  'store': 1719,
#  'shelf': 63,
#  'started': 910,
#  'yesterday': 643,
#  'keep': 2191,
#  'back': 3647,
#  'coffee': 1326,
#  'figured': 258,
#  'might': 2856,
#  'along': 1634,
#  'benefits': 54,
#  'OK': 410,
#  'NEVER': 140,
#  'buy': 1231,
#  'jarred': 138,
#  'terrific': 806,
#  'early': 296,
#  'day': 4411,
#  'cant': 3569,
#  'wait': 2246,
#  'hint': 442,
#  'spice': 1783,
#  'omitted': 1634,
#  'flakes': 1254,
#  'small': 3266,
#  'tenderness': 48,
#  'rub': 489,
#  'right': 4670,
#  'cold': 1565,
#  'yogurt': 1437,
#  'whipped': 847,
#  'or': 12433,
#  'cumin': 893,
#  'curry': 935,
#  'cinnamon': 2763,
#  'try': 9694,
#  'Chinese': 218,
#  'resist': 120,
#  'splash': 307,
#  'squash': 803,
#  'microwave': 1234,
#  'minute': 740,
#  'blasts': 1,
#  'peel': 409,
#  'when': 9537,
#  'freeze': 891,
#  'flesh': 42,
#  'Carrots': 39,
#  'eaten': 1039,
#  'highly': 552,
#  'recommend': 1661,
#  'these': 16355,
#  'yet': 1551,
#  'treats': 178,
#  'plastic': 303,
#  'popsicle': 10,
#  'molds': 21,
#  'halved': 1315,
#  'popsicles': 7,
#  'They': 5948,
#  'adults': 281,
#  'gone': 1024,
#  'crazy': 437,
#  'eating': 2231,
#  'And': 2798,
#  'since': 4814,
#  'theyre': 505,
#  'Barb': 106,
#  'become': 735,
#  'modifications': 244,
#  'laziness': 14,
#  'semi': 81,
#  'breasts': 1414,
#  'browned': 778,
#  'rest': 2084,
#  'through': 1690,
#  'omit': 599,
#  'avoid': 199,
#  'sugaryness': 1,
#  'commented': 164,
#  'PERFECT': 248,
#  'As': 1555,
#  'couscous': 289,
#  'broth': 2831,
#  'soak': 339,
#  'margarine': 511,
#  'garlicbuttery': 1,
#  'certainly': 921,
#  'disappoint': 137,
#  'Miraklegirl': 10,
#  'fantastic': 2774,
#  'soft': 1696,
#  'chewy': 635,
#  'loveddd': 1,
#  'friends': 1426,
#  'chopped': 3307,
#  'mars': 2,
#  'bar': 318,
#  'chocolate': 5277,
#  'chips': 2744,
#  'worked': 3226,
#  'charm': 118,
#  'definitely': 6297,
#  'THANKS': 220,
#  'Christmas': 1590,
#  'Thank': 9766,
#  'treat': 1637,
#  'dressing': 3262,
#  'sesame': 660,
#  'seeds': 1233,
#  'lamb': 501,
#  'marinaded': 66,
#  'spices': 2145,
#  'simply': 752,
#  'WONDERFUL': 311,
#  'any': 6647,
#  'salt': 6443,
#  'substitution': 161,
#  'necessitydidnt': 1,
#  'hash': 174,
#  'browns': 143,
#  'potatoes': 5827,
#  'About': 76,
#  'peeked': 5,
#  'browning': 375,
#  'bottom': 1305,
#  'werent': 578,
#  'needed': 3038,
#  'water': 5337,
#  'DUH': 3,
#  'remember': 678,
#  'how': 5295,
#  'Ill': 5991,
#  'redo': 10,
#  'die': 416,
#  'truly': 633,
#  'give': 3314,
#  'againbrbrI': 4,
#  'drumsticks': 87,
#  'wings': 603,
#  'grocery': 461,
#  'low': 2640,
#  'sodium': 541,
#  'soy': 1230,
#  'forget': 255,
#  'know': 3853,
#  'affected': 68,
#  'thicker': 525,
#  'barbecue': 230,
#  'move': 92,
#  'fluid': 35,
#  'thicken': 787,
#  'starch': 258,
#  'flour': 5100,
#  'stated': 940,
#  'mom': 897,
#  'Northern': 39,
#  'Ireland': 21,
#  'introduced': 38,
#  'Marmite': 13,
#  'age': 64,
#  'rye': 170,
#  'marmite': 9,
#  'dip': 1467,
#  'eggs': 2170,
#  'Paulas': 16,
#  'Peach': 24,
#  'Dump': 9,
#  'Cake': 276,
#  'forward': 800,
#  'her': 1498,
#  'call': 580,
#  'future': 793,
#  'dessert': 1811,
#  'fix': 557,
#  'short': 504,
#  'notice': 192,
#  'Wow': 1795,
#  'What': 2609,
#  'amazing': 2470,
#  'stuff': 1401,
#  'Hokey': 4,
#  'Pokey': 6,
#  'icecream': 99,
#  'this\nI': 5,
#  'shocked': 69,
#  'complete': 265,
#  'colour': 187,
#  'after': 5843,
#  'stirring': 264,
#  'baking': 3927,
#  'soda': 449,
#  'quick\nI': 1,
#  'burned': 244,
#  'ours': 310,
#  'difficult': 418,
#  'spread': 1280,
#  'flat': 430,
#  'first': 6857,
#  'go\nNext': 1,
#  'whats': 148,
#  'come': 1668,
#  'manual': 11,
#  'method': 846,
#  'directions': 1937,
#  'follow': 1060,
#  'produced': 157,
#  'results': 1273,
#  'light': 3078,
#  'zaatar': 20,
#  'topping': 2087,
#  'keeper': 4585,
#  'Best': 702,
#  'event': 292,
#  'recommended': 537,
#  'awalde': 11,
#  'sorry': 708,
#  'wasnt': 3289,
#  'There': 1143,
#  'something': 4246,
#  'missing': 651,
#  'turn': 1194,
#  'turmeric': 94,
#  'strange': 164,
#  'color': 1031,
#  'unappealing': 20,
#  'smelled': 722,
#  'carne': 7,
#  'asada': 6,
#  'maybe': 2359,
#  'expecting': 363,
#  'cooked': 6945,
#  'delightful': 406,
#  'while': 3327,
#  'grilling': 335,
#  'meet': 58,
#  'expectations': 95,
#  'watching': 234,
#  'think': 11026,
#  'tweak': 212,
#  'sure': 6410,
#  'Did': 460,
#  'microwaved': 190,
#  'spuds': 49,
#  'onions': 4043,
#  'night': 3696,
#  'onion': 5486,
#  'each': 2447,
#  'their': 1560,
#  'flavours': 658,
#  'distinctly\r\nGood': 1,
#  'veggie': 718,
#  'Lovely': 407,
#  'beautiful': 1006,
#  'Thanksgiving': 862,
#  'morning': 1650,
#  'With': 671,
#  'link': 51,
#  'sliced': 2177,
#  'fruit': 1367,
#  'visiting': 128,
#  'grands': 7,
#  'Kittencal': 685,
#  'teach': 25,
#  'high': 1486,
#  'school': 442,
#  'foods': 328,
#  'class': 142,
#  'studying': 10,
#  'legumes': 6,
#  'sour': 2648,
#  'cream': 9349,
#  'Tobasco': 27,
#  'tortilla': 590,
#  'While': 419,
#  'students': 48,
#  'look': 1591,
#  'Not': 1866,
#  'single': 372,
#  'student': 53,
#  'disliked': 21,
#  'starting': 258,
#  'period': 68,
#  'reheating': 67,
#  'Many': 187,
#  'requested': 375,
#  'second': 1699,
#  'copy': 174,
#  'take': 2333,
#  'home': 2245,
#  'Great': 5961,
#  'job': 238,
#  'definately': 1075,
#  'lemon': 4220,
#  'zest': 806,
#  'devine': 48,
#  'reheat': 181,
#  'crunchiness': 42,
#  'which': 8103,
#  'scone': 128,
#  'cranberries': 650,
#  'YummoBe': 1,
#  'heaps': 43,
#  'now': 5053,
#  'recipe\r\n': 48,
#  'momaphet': 13,
#  's': 282,
#  'ridiculously': 37,
#  'crisp': 966,
#  'sitting': 367,
#  'here': 2925,
#  'wishing': 41,
#  'batch': 2693,
#  'got': 4187,
#  'blasting': 2,
#  'coconut': 1690,
#  'Just': 2362,
#  'dh': 297,
#  'wont': 1285,
#  'gems': 49,
#  'box': 743,
#  'Culinary': 129,
#  'Quest': 125,
#  'Suitcase': 16,
#  'Gourmets': 27,
#  'quartered': 165,
#  'easily': 1048,
#  'Sarah': 42,
#  'Well': 1100,
#  'us': 3811,
#  'scarfed': 60,
#  'avocado': 434,
#  'finely': 532,
#  'fat': 3345,
#  'philadelphia': 2,
#  'base': 790,
#  'dolloped': 5,
#  'does': 1838,
#  'melt': 546,
#  'TFC': 3,
#  'Make': 472,
#  'Recipe': 2615,
#  'edition': 14,
#  'Delicious': 3268,
#  'Doesnt': 57,
#  'canes': 24,
#  'At': 452,
#  'Too': 240,
#  'mayo': 1034,
#  'Having': 133,
#  'lots': 1190,
#  'MENORCA': 1,
#  'rind': 168,
#  'find': 3593,
#  'may': 2495,
#  'round': 666,
#  'loose': 111,
#  'tin': 369,
#  'Almond': 64,
#  'rapberries': 1,
#  'themits': 1,
#  'winner': 1327,
#  'everytime': 101,
#  'needs': 853,
#  'tweaked': 165,
#  'spicier': 120,
#  'taco': 476,
#  'homemade': 1626,
#  'Straightforward': 2,
#  'adding': 3908,
#  'guacamole': 153,
#  'finish': 511,
#  'bite': 1107,
#  'A': 5828,
#  'square': 203,
#  'super': 1993,
#  'many': 3212,
#  'shine': 63,
#  'Moist': 182,
#  'flavorful': 2091,
#  'under': 697,
#  'skin': 691,
#  'rosemary': 874,
#  'basil': 1525,
#  'overwhelming': 174,
#  'Really': 1624,
#  'blend': 1417,
#  'thighs': 646,
#  'sooner': 81,
#  'Summer': 105,
#  'Comfort': 210,
#  'Cafe': 145,
#  'Followed': 619,
#  'tee': 86,
#  'fell': 465,
#  'middle': 640,
#  'during': 990,
#  'wasted': 78,
#  'money': 192,
#  'garbage': 37,
#  'DELICIOUS': 497,
#  'touch': 1067,
#  'Sounds': 88,
#  'although': 1252,
#  'replace': 253,
#  'cucumber': 382,
#  'hate': 404,
#  'lol': 745,
#  'pickles': 211,
#  'reason': 644,
#  'NO': 185,
#  'IDEA': 8,
#  'convert': 57,
#  'grams': 153,
#  'normal': 346,
#  'measurements': 259,
#  'Hey': 142,
#  'guys': 195,
#  'why': 1063,
#  'option': 321,
#  'Everyone': 1884,
#  'salad': 5496,
#  'roll': 978,
#  'Probably': 158,
#  'should': 2258,
#  'Miss': 264,
#  'Lillie': 1,
#  'Kauitzsch': 1,
#  'proud': 95,
#  'If': 2364,
#  'amp': 1090,
#  'powder': 3957,
#  'timemight': 1,
#  'bell': 812,
#  'heard': 279,
#  'frosting': 1782,
#  'Penzys': 9,
#  'Dark': 101,
#  'Cocoa': 50,
#  'On': 267,
#  'poster': 94,
#  'TBSP': 90,
#  'syrup': 1650,
#  'glossy': 22,
#  'Be': 259,
#  'sift': 34,
#  'double': 1947,
#  'layer': 952,
#  'cake': 6951,
#  'received': 346,
#  'requests': 224,
#  'amazed': 141,
#  'Plus': 199,
#  'freezes': 144,
#  'check': 219,
#  'Since': 842,
#  'drink': 1448,
#  'most': 2338,
#  'everyday': 148,
#  ...}

# %%
# %time get_word_reviews_count_opt(new_recipes)
# Out:
# 2.43 s ± 73 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
get_word_reviews_count(new_recipes)
# Out:
# {'Last': 97,
#  'week': 1509,
#  'whole': 5782,
#  'sides': 458,
#  'of': 109239,
#  'frozen': 2943,
#  'salmon': 1032,
#  'fillet': 92,
#  'was': 89617,
#  'on': 36121,
#  'sale': 262,
#  'in': 62796,
#  'my': 44644,
#  'local': 572,
#  'supermarket': 95,
#  'so': 46848,
#  'I': 288243,
#  'bought': 1514,
#  'tons': 163,
#  'okay': 600,
#  'only': 14209,
#  '': 330966,
#  'but': 43035,
#  'total': 512,
#  'weight': 216,
#  'over': 9801,
#  'pounds': 291,
#  'This': 39555,
#  'recipe': 71751,
#  'is': 56519,
#  'perfect': 7807,
#  'for': 123162,
#  'even': 8074,
#  'though': 4942,
#  'it': 133219,
#  'calls': 525,
#  'steaks': 511,
#  'cut': 6848,
#  'up': 16178,
#  'the': 266530,
#  'into': 7085,
#  'individual': 314,
#  'portions': 214,
#  'and': 219215,
#  'followed': 4880,
#  'instructions': 1007,
#  'exactly': 4625,
#  'Im': 8330,
#  'one': 17615,
#  'those': 2419,
#  'food': 3498,
#  'combining': 78,
#  'diets': 45,
#  'left': 5064,
#  'out': 25697,
#  'white': 3690,
#  'wine': 1760,
#  'added': 22099,
#  'just': 25271,
#  'a': 166467,
#  'dash': 547,
#  'vinegar': 1946,
#  'instead': 11644,
#  'little': 16798,
#  'bit': 11153,
#  'not': 23840,
#  'enough': 5516,
#  'to': 132170,
#  'change': 4464,
#  'taste': 11290,
#  'dish': 9853,
#  'Super': 867,
#  'yummy': 5045,
#  'leftovers': 2318,
#  'lunch': 2501,
#  'today': 1915,
#  'lucky': 127,
#  'me': 10937,
#  'So': 4779,
#  'simple': 4911,
#  'tasty': 8112,
#  'used': 45538,
#  'yellow': 851,
#  'capsicum': 59,
#  'place': 2166,
#  'green': 4639,
#  'because': 11649,
#  'thats': 2027,
#  'what': 7676,
#  'had': 28047,
#  'hand': 3937,
#  'came': 5279,
#  'together': 5451,
#  'fast': 1387,
#  'Perfect': 1136,
#  'meal': 4348,
#  'if': 7448,
#  'you': 28143,
#  'dont': 7522,
#  'have': 35532,
#  'lot': 3905,
#  'time': 24744,
#  'Easy': 2302,
#  'healthy': 1854,
#  'Thanks': 32325,
#  'Stardustannie': 11,
#  'Made': 13439,
#  'PAC': 1827,
#  'Fall': 758,
#  'Very': 8891,
#  'nice': 9478,
#  'breakfast': 2266,
#  'HH': 7,
#  'easy': 21683,
#  'make': 37321,
#  'with': 59275,
#  'fresh': 8213,
#  'hot': 4172,
#  'coffe': 16,
#  'Instead': 908,
#  'toast': 703,
#  'served': 6550,
#  'by': 6670,
#  'Paula': 222,
#  'G': 44,
#  'that': 38949,
#  'made': 39363,
#  'earlier': 215,
#  'turned': 6379,
#  'great': 27326,
#  'will': 24097,
#  'be': 25514,
#  'regular': 3155,
#  'our': 6908,
#  'house': 2466,
#  'DH': 4114,
#  'loved': 13957,
#  'them': 25768,
#  'These': 8403,
#  'are': 15758,
#  'favorite': 3357,
#  'holidays': 340,
#  'children': 462,
#  'We': 12628,
#  'also': 15275,
#  'use': 17487,
#  'Rolo': 6,
#  'candies': 83,
#  'kisses': 84,
#  'Excellent': 2602,
#  'soup': 7150,
#  'The': 25845,
#  'tomato': 2427,
#  'flavor': 13426,
#  'this': 93873,
#  'freezer': 1329,
#  'tag': 1490,
#  'froze': 679,
#  'beautifully': 833,
#  'prepared': 1005,
#  'as': 35863,
#  'directed': 1353,
#  'then': 8692,
#  'allowed': 234,
#  'cool': 1160,
#  'container': 348,
#  'thawed': 283,
#  'fridge': 1463,
#  'reheated': 297,
#  'stovetop': 253,
#  'Worked': 253,
#  'perfectly': 1908,
#  'forgot': 1367,
#  'add': 13152,
#  'skim': 437,
#  'milk': 5487,
#  'still': 6783,
#  'tasted': 4443,
#  'pretty': 3762,
#  'good': 31181,
#  'Dancer': 72,
#  'dinner': 6102,
#  'excellent': 3167,
#  'finally': 543,
#  'found': 5203,
#  'tuna': 626,
#  'casserole': 1214,
#  'we': 13106,
#  'enjoy': 1480,
#  'thanks': 3937,
#  'When': 1641,
#  'snapped': 10,
#  'picture': 574,
#  'review': 1749,
#  'toasted': 837,
#  'pecans': 961,
#  'at': 15556,
#  'party': 1953,
#  'Prime': 23,
#  'Rib': 36,
#  'Ten': 16,
#  'stars': 3566,
#  'Lennie': 87,
#  'combination': 2276,
#  'flavors': 3266,
#  'reduce': 929,
#  'rice': 5454,
#  'cilantro': 1184,
#  'next': 10208,
#  'sharing': 11629,
#  'honKitten': 39,
#  'Oh': 1992,
#  'Bergy': 188,
#  'wonderful': 9253,
#  'cakes': 691,
#  'awesome': 2545,
#  'Fast': 158,
#  'put': 8603,
#  'get': 6853,
#  'fish': 1594,
#  'where': 997,
#  'live': 480,
#  'yuck': 26,
#  'am': 6321,
#  'tired': 165,
#  'trying': 1923,
#  'new': 2864,
#  'recipes': 4118,
#  'help': 918,
#  'lack': 181,
#  'quality': 492,
#  'But': 2905,
#  'problem': 1317,
#  'did': 18661,
#  'cloves': 1189,
#  'garlic': 8961,
#  'seasoned': 865,
#  'bread': 8116,
#  'crumbs': 1210,
#  'Smash': 3,
#  'Seasoning': 232,
#  'It': 19513,
#  'has': 4917,
#  'no': 6211,
#  'salt\r\nI': 6,
#  'tartar': 84,
#  'sauce': 16769,
#  'go': 4057,
#  '\r\nThank': 66,
#  'very': 26040,
#  'moist': 3831,
#  'cornbread': 529,
#  'two': 4806,
#  'days': 1168,
#  'later': 907,
#  'less': 3398,
#  'sugar': 9368,
#  'honey': 1834,
#  'farm': 84,
#  'butterand': 3,
#  'corn': 2728,
#  'about': 13225,
#  'ears': 59,
#  'Served': 1975,
#  'ribs': 1627,
#  'grill': 1288,
#  'Ive': 6503,
#  'been': 5841,
#  'making': 11171,
#  'past': 540,
#  'several': 1729,
#  'years': 2425,
#  'Its': 3661,
#  'always': 4249,
#  'extremely': 602,
#  'posting': 9924,
#  'generic': 34,
#  'sweetened': 261,
#  'condensed': 237,
#  'works': 893,
#  'well': 9879,
#  'tastes': 2832,
#  'costs': 20,
#  'usually': 1948,
#  'WalMart': 11,
#  'brand': 423,
#  'Exceptional': 15,
#  'delicious': 14634,
#  'really': 19695,
#  'liked': 5738,
#  'weekday': 73,
#  'leftover': 1936,
#  'looking': 3138,
#  'different': 4105,
#  'ways': 498,
#  'ground': 2519,
#  'beef': 3224,
#  'love': 9914,
#  'sandwich': 1316,
#  'alot': 596,
#  'sooo': 604,
#  'Lite': 33,
#  'brown': 3823,
#  'mustard': 1542,
#  'horse': 6,
#  'relish': 242,
#  'some': 21057,
#  'olives': 925,
#  'ons': 2,
#  'Next': 3516,
#  'balsamic': 529,
#  'dressingit': 3,
#  'mind': 483,
#  'cbreezie': 2,
#  'affordable': 33,
#  'addicting': 105,
#  'Our': 366,
#  'household': 157,
#  'Blessings': 8,
#  'chef': 414,
#  'never': 5019,
#  'apple': 1610,
#  'orange': 1778,
#  'juice': 3949,
#  'makes': 3372,
#  'all': 18010,
#  'difference': 1215,
#  'texture': 3618,
#  'wonderful\r\nThank': 4,
#  'You': 2450,
#  'were': 21189,
#  'grated': 977,
#  'cheddar': 1776,
#  'cheese': 11944,
#  'top': 6408,
#  'minutes': 8327,
#  'before': 8099,
#  'they': 17014,
#  'done': 2549,
#  'seasoning': 2861,
#  'best': 5295,
#  'pizza': 1250,
#  'dough': 3393,
#  'Other': 576,
#  'tried': 4747,
#  'machine': 760,
#  'way': 8213,
#  'too': 16024,
#  'sticky': 595,
#  'Leaving': 11,
#  'msg': 32,
#  'fine': 2128,
#  'divide': 63,
#  'half': 9003,
#  'knead': 106,
#  'floured': 90,
#  'surface': 96,
#  'few': 4934,
#  'times': 3323,
#  'stretch': 81,
#  'cirle': 1,
#  'like': 20964,
#  'bake': 2099,
#  'castiron': 25,
#  'skillet': 650,
#  'brush': 168,
#  'pan': 5518,
#  'olive': 2084,
#  'oil': 5607,
#  'sprinkle': 644,
#  'crust': 2487,
#  'lowest': 29,
#  'rack': 362,
#  'oven': 5135,
#  'saw': 752,
#  'Giada': 9,
#  'Today': 120,
#  'show': 212,
#  'last': 4600,
#  'month': 422,
#  'wanted': 2838,
#  'compare': 147,
#  'family': 8392,
#  'being': 1865,
#  'Marsala': 29,
#  'dry': 3015,
#  'red': 4608,
#  'chickenturkey': 4,
#  'sausage': 1639,
#  'cutting': 584,
#  'sausages': 149,
#  'finishing': 132,
#  'cooking': 5412,
#  'stove': 768,
#  'My': 14460,
#  'traditionally': 29,
#  'serves': 178,
#  'peppers': 2253,
#  'polentathis': 1,
#  'compared': 132,
#  'probably': 2736,
#  'calories': 679,
#  'heats': 11,
#  'kitchen': 800,
#  'summertime': 75,
#  'meatloaf': 605,
#  'took': 3867,
#  'reviewers': 889,
#  'suggestion': 619,
#  'another': 4903,
#  'crock': 1080,
#  'pot': 2565,
#  'sweet': 6989,
#  'tangy': 411,
#  'wonder': 276,
#  'addition': 2228,
#  'again': 21144,
#  'deliciously': 99,
#  'can': 9814,
#  'literally': 162,
#  'thrown': 106,
#  'soups': 338,
#  'i': 7877,
#  'ever': 4458,
#  'uncomplicated': 11,
#  'from': 12975,
#  'appealed': 21,
#  'simplicity': 213,
#  'quick': 4909,
#  'could': 6482,
#  'both': 2894,
#  'anything': 1780,
#  'see': 2343,
#  'more': 18338,
#  'substance': 25,
#  'nothing': 777,
#  'thankfully': 29,
#  'rustic': 49,
#  'roasted': 1303,
#  'balance': 454,
#  'other': 7203,
#  'ingredients': 6112,
#  'paul': 2,
#  'newman': 1,
#  'marinara': 133,
#  'cup': 8138,
#  'let': 2922,
#  'simmer': 447,
#  'would': 16822,
#  'definitly': 60,
#  'much': 15206,
#  'plus': 925,
#  'tea': 847,
#  'aroma': 369,
#  'steeping': 11,
#  'five': 713,
#  'large': 2229,
#  'glass': 659,
#  'ice': 1597,
#  'enjoyed': 7164,
#  'Good': 1692,
#  'marinade': 1474,
#  'Jack': 194,
#  'Daniels': 34,
#  'except': 2181,
#  'didnt': 16680,
#  'marinate': 390,
#  'quite': 3840,
#  'long': 2412,
#  'hours': 3234,
#  'grilled': 1304,
#  'counter': 188,
#  'everyone': 2770,
#  'Even': 1384,
#  'who': 3207,
#  'doesnt': 2209,
#  'dressed': 67,
#  'said': 3953,
#  'Almost': 109,
#  'teriyaki': 103,
#  'baked': 4392,
#  'potato': 2016,
#  'asparagus': 649,
#  'Fantastic': 799,
#  'earning': 2,
#  'raves': 144,
#  'table': 770,
#  'homegirl': 12,
#  'comforting': 228,
#  'lowsodium': 77,
#  'lowfat': 491,
#  'chicken': 13602,
#  'stock': 1189,
#  'butter': 7721,
#  'dried': 2404,
#  'parsley': 1216,
#  'do': 7567,
#  'than': 10347,
#  'an': 10577,
#  'hour': 1772,
#  'Me': 82,
#  'course': 892,
#  'Breezermom': 9,
#  'Market': 208,
#  'game': 1202,
#  'Will': 3440,
#  'kids': 3696,
#  'weekend': 746,
#  'your': 6423,
#  'cookies': 2942,
#  'already': 1785,
#  'Triple': 18,
#  'Chocolates': 2,
#  'Were': 143,
#  'addicted': 91,
#  'jam': 631,
#  'its': 7254,
#  'tend': 205,
#  'vinegarphobic': 1,
#  'adore': 109,
#  'black': 1664,
#  'pepper': 6580,
#  'increase': 510,
#  'Also': 3063,
#  'once': 1754,
#  'strawberries': 823,
#  'cook': 4881,
#  'down': 3702,
#  'masher': 53,
#  'break': 208,
#  'consistency': 980,
#  'kick': 1065,
#  'fun': 1140,
#  'English': 160,
#  'muffins': 1921,
#  'peanut': 1369,
#  'jelly': 403,
#  'sandwiches': 859,
#  'wheat': 1923,
#  'wish': 849,
#  'canning': 170,
#  'store': 1719,
#  'shelf': 63,
#  'started': 910,
#  'yesterday': 643,
#  'keep': 2191,
#  'back': 3647,
#  'coffee': 1326,
#  'figured': 258,
#  'might': 2856,
#  'along': 1634,
#  'benefits': 54,
#  'OK': 410,
#  'NEVER': 140,
#  'buy': 1231,
#  'jarred': 138,
#  'terrific': 806,
#  'early': 296,
#  'day': 4411,
#  'cant': 3569,
#  'wait': 2246,
#  'hint': 442,
#  'spice': 1783,
#  'omitted': 1634,
#  'flakes': 1254,
#  'small': 3266,
#  'tenderness': 48,
#  'rub': 489,
#  'right': 4670,
#  'cold': 1565,
#  'yogurt': 1437,
#  'whipped': 847,
#  'or': 12433,
#  'cumin': 893,
#  'curry': 935,
#  'cinnamon': 2763,
#  'try': 9694,
#  'Chinese': 218,
#  'resist': 120,
#  'splash': 307,
#  'squash': 803,
#  'microwave': 1234,
#  'minute': 740,
#  'blasts': 1,
#  'peel': 409,
#  'when': 9537,
#  'freeze': 891,
#  'flesh': 42,
#  'Carrots': 39,
#  'eaten': 1039,
#  'highly': 552,
#  'recommend': 1661,
#  'these': 16355,
#  'yet': 1551,
#  'treats': 178,
#  'plastic': 303,
#  'popsicle': 10,
#  'molds': 21,
#  'halved': 1315,
#  'popsicles': 7,
#  'They': 5948,
#  'adults': 281,
#  'gone': 1024,
#  'crazy': 437,
#  'eating': 2231,
#  'And': 2798,
#  'since': 4814,
#  'theyre': 505,
#  'Barb': 106,
#  'become': 735,
#  'modifications': 244,
#  'laziness': 14,
#  'semi': 81,
#  'breasts': 1414,
#  'browned': 778,
#  'rest': 2084,
#  'through': 1690,
#  'omit': 599,
#  'avoid': 199,
#  'sugaryness': 1,
#  'commented': 164,
#  'PERFECT': 248,
#  'As': 1555,
#  'couscous': 289,
#  'broth': 2831,
#  'soak': 339,
#  'margarine': 511,
#  'garlicbuttery': 1,
#  'certainly': 921,
#  'disappoint': 137,
#  'Miraklegirl': 10,
#  'fantastic': 2774,
#  'soft': 1696,
#  'chewy': 635,
#  'loveddd': 1,
#  'friends': 1426,
#  'chopped': 3307,
#  'mars': 2,
#  'bar': 318,
#  'chocolate': 5277,
#  'chips': 2744,
#  'worked': 3226,
#  'charm': 118,
#  'definitely': 6297,
#  'THANKS': 220,
#  'Christmas': 1590,
#  'Thank': 9766,
#  'treat': 1637,
#  'dressing': 3262,
#  'sesame': 660,
#  'seeds': 1233,
#  'lamb': 501,
#  'marinaded': 66,
#  'spices': 2145,
#  'simply': 752,
#  'WONDERFUL': 311,
#  'any': 6647,
#  'salt': 6443,
#  'substitution': 161,
#  'necessitydidnt': 1,
#  'hash': 174,
#  'browns': 143,
#  'potatoes': 5827,
#  'About': 76,
#  'peeked': 5,
#  'browning': 375,
#  'bottom': 1305,
#  'werent': 578,
#  'needed': 3038,
#  'water': 5337,
#  'DUH': 3,
#  'remember': 678,
#  'how': 5295,
#  'Ill': 5991,
#  'redo': 10,
#  'die': 416,
#  'truly': 633,
#  'give': 3314,
#  'againbrbrI': 4,
#  'drumsticks': 87,
#  'wings': 603,
#  'grocery': 461,
#  'low': 2640,
#  'sodium': 541,
#  'soy': 1230,
#  'forget': 255,
#  'know': 3853,
#  'affected': 68,
#  'thicker': 525,
#  'barbecue': 230,
#  'move': 92,
#  'fluid': 35,
#  'thicken': 787,
#  'starch': 258,
#  'flour': 5100,
#  'stated': 940,
#  'mom': 897,
#  'Northern': 39,
#  'Ireland': 21,
#  'introduced': 38,
#  'Marmite': 13,
#  'age': 64,
#  'rye': 170,
#  'marmite': 9,
#  'dip': 1467,
#  'eggs': 2170,
#  'Paulas': 16,
#  'Peach': 24,
#  'Dump': 9,
#  'Cake': 276,
#  'forward': 800,
#  'her': 1498,
#  'call': 580,
#  'future': 793,
#  'dessert': 1811,
#  'fix': 557,
#  'short': 504,
#  'notice': 192,
#  'Wow': 1795,
#  'What': 2609,
#  'amazing': 2470,
#  'stuff': 1401,
#  'Hokey': 4,
#  'Pokey': 6,
#  'icecream': 99,
#  'this\nI': 5,
#  'shocked': 69,
#  'complete': 265,
#  'colour': 187,
#  'after': 5843,
#  'stirring': 264,
#  'baking': 3927,
#  'soda': 449,
#  'quick\nI': 1,
#  'burned': 244,
#  'ours': 310,
#  'difficult': 418,
#  'spread': 1280,
#  'flat': 430,
#  'first': 6857,
#  'go\nNext': 1,
#  'whats': 148,
#  'come': 1668,
#  'manual': 11,
#  'method': 846,
#  'directions': 1937,
#  'follow': 1060,
#  'produced': 157,
#  'results': 1273,
#  'light': 3078,
#  'zaatar': 20,
#  'topping': 2087,
#  'keeper': 4585,
#  'Best': 702,
#  'event': 292,
#  'recommended': 537,
#  'awalde': 11,
#  'sorry': 708,
#  'wasnt': 3289,
#  'There': 1143,
#  'something': 4246,
#  'missing': 651,
#  'turn': 1194,
#  'turmeric': 94,
#  'strange': 164,
#  'color': 1031,
#  'unappealing': 20,
#  'smelled': 722,
#  'carne': 7,
#  'asada': 6,
#  'maybe': 2359,
#  'expecting': 363,
#  'cooked': 6945,
#  'delightful': 406,
#  'while': 3327,
#  'grilling': 335,
#  'meet': 58,
#  'expectations': 95,
#  'watching': 234,
#  'think': 11026,
#  'tweak': 212,
#  'sure': 6410,
#  'Did': 460,
#  'microwaved': 190,
#  'spuds': 49,
#  'onions': 4043,
#  'night': 3696,
#  'onion': 5486,
#  'each': 2447,
#  'their': 1560,
#  'flavours': 658,
#  'distinctly\r\nGood': 1,
#  'veggie': 718,
#  'Lovely': 407,
#  'beautiful': 1006,
#  'Thanksgiving': 862,
#  'morning': 1650,
#  'With': 671,
#  'link': 51,
#  'sliced': 2177,
#  'fruit': 1367,
#  'visiting': 128,
#  'grands': 7,
#  'Kittencal': 685,
#  'teach': 25,
#  'high': 1486,
#  'school': 442,
#  'foods': 328,
#  'class': 142,
#  'studying': 10,
#  'legumes': 6,
#  'sour': 2648,
#  'cream': 9349,
#  'Tobasco': 27,
#  'tortilla': 590,
#  'While': 419,
#  'students': 48,
#  'look': 1591,
#  'Not': 1866,
#  'single': 372,
#  'student': 53,
#  'disliked': 21,
#  'starting': 258,
#  'period': 68,
#  'reheating': 67,
#  'Many': 187,
#  'requested': 375,
#  'second': 1699,
#  'copy': 174,
#  'take': 2333,
#  'home': 2245,
#  'Great': 5961,
#  'job': 238,
#  'definately': 1075,
#  'lemon': 4220,
#  'zest': 806,
#  'devine': 48,
#  'reheat': 181,
#  'crunchiness': 42,
#  'which': 8103,
#  'scone': 128,
#  'cranberries': 650,
#  'YummoBe': 1,
#  'heaps': 43,
#  'now': 5053,
#  'recipe\r\n': 48,
#  'momaphet': 13,
#  's': 282,
#  'ridiculously': 37,
#  'crisp': 966,
#  'sitting': 367,
#  'here': 2925,
#  'wishing': 41,
#  'batch': 2693,
#  'got': 4187,
#  'blasting': 2,
#  'coconut': 1690,
#  'Just': 2362,
#  'dh': 297,
#  'wont': 1285,
#  'gems': 49,
#  'box': 743,
#  'Culinary': 129,
#  'Quest': 125,
#  'Suitcase': 16,
#  'Gourmets': 27,
#  'quartered': 165,
#  'easily': 1048,
#  'Sarah': 42,
#  'Well': 1100,
#  'us': 3811,
#  'scarfed': 60,
#  'avocado': 434,
#  'finely': 532,
#  'fat': 3345,
#  'philadelphia': 2,
#  'base': 790,
#  'dolloped': 5,
#  'does': 1838,
#  'melt': 546,
#  'TFC': 3,
#  'Make': 472,
#  'Recipe': 2615,
#  'edition': 14,
#  'Delicious': 3268,
#  'Doesnt': 57,
#  'canes': 24,
#  'At': 452,
#  'Too': 240,
#  'mayo': 1034,
#  'Having': 133,
#  'lots': 1190,
#  'MENORCA': 1,
#  'rind': 168,
#  'find': 3593,
#  'may': 2495,
#  'round': 666,
#  'loose': 111,
#  'tin': 369,
#  'Almond': 64,
#  'rapberries': 1,
#  'themits': 1,
#  'winner': 1327,
#  'everytime': 101,
#  'needs': 853,
#  'tweaked': 165,
#  'spicier': 120,
#  'taco': 476,
#  'homemade': 1626,
#  'Straightforward': 2,
#  'adding': 3908,
#  'guacamole': 153,
#  'finish': 511,
#  'bite': 1107,
#  'A': 5828,
#  'square': 203,
#  'super': 1993,
#  'many': 3212,
#  'shine': 63,
#  'Moist': 182,
#  'flavorful': 2091,
#  'under': 697,
#  'skin': 691,
#  'rosemary': 874,
#  'basil': 1525,
#  'overwhelming': 174,
#  'Really': 1624,
#  'blend': 1417,
#  'thighs': 646,
#  'sooner': 81,
#  'Summer': 105,
#  'Comfort': 210,
#  'Cafe': 145,
#  'Followed': 619,
#  'tee': 86,
#  'fell': 465,
#  'middle': 640,
#  'during': 990,
#  'wasted': 78,
#  'money': 192,
#  'garbage': 37,
#  'DELICIOUS': 497,
#  'touch': 1067,
#  'Sounds': 88,
#  'although': 1252,
#  'replace': 253,
#  'cucumber': 382,
#  'hate': 404,
#  'lol': 745,
#  'pickles': 211,
#  'reason': 644,
#  'NO': 185,
#  'IDEA': 8,
#  'convert': 57,
#  'grams': 153,
#  'normal': 346,
#  'measurements': 259,
#  'Hey': 142,
#  'guys': 195,
#  'why': 1063,
#  'option': 321,
#  'Everyone': 1884,
#  'salad': 5496,
#  'roll': 978,
#  'Probably': 158,
#  'should': 2258,
#  'Miss': 264,
#  'Lillie': 1,
#  'Kauitzsch': 1,
#  'proud': 95,
#  'If': 2364,
#  'amp': 1090,
#  'powder': 3957,
#  'timemight': 1,
#  'bell': 812,
#  'heard': 279,
#  'frosting': 1782,
#  'Penzys': 9,
#  'Dark': 101,
#  'Cocoa': 50,
#  'On': 267,
#  'poster': 94,
#  'TBSP': 90,
#  'syrup': 1650,
#  'glossy': 22,
#  'Be': 259,
#  'sift': 34,
#  'double': 1947,
#  'layer': 952,
#  'cake': 6951,
#  'received': 346,
#  'requests': 224,
#  'amazed': 141,
#  'Plus': 199,
#  'freezes': 144,
#  'check': 219,
#  'Since': 842,
#  'drink': 1448,
#  'most': 2338,
#  'everyday': 148,
#  ...}

# %%
get_word_reviews_count_opt(new_recipes)
# Out:
# {'Last': 97,
#  'week': 1509,
#  'whole': 5782,
#  'sides': 458,
#  'of': 109239,
#  'frozen': 2943,
#  'salmon': 1032,
#  'fillet': 92,
#  'was': 89617,
#  'on': 36121,
#  'sale': 262,
#  'in': 62796,
#  'my': 44644,
#  'local': 572,
#  'supermarket': 95,
#  'so': 46848,
#  'I': 288243,
#  'bought': 1514,
#  'tons': 163,
#  'okay': 600,
#  'only': 14209,
#  '': 330966,
#  'but': 43035,
#  'total': 512,
#  'weight': 216,
#  'over': 9801,
#  'pounds': 291,
#  'This': 39555,
#  'recipe': 71751,
#  'is': 56519,
#  'perfect': 7807,
#  'for': 123162,
#  'even': 8074,
#  'though': 4942,
#  'it': 133219,
#  'calls': 525,
#  'steaks': 511,
#  'cut': 6848,
#  'up': 16178,
#  'the': 266530,
#  'into': 7085,
#  'individual': 314,
#  'portions': 214,
#  'and': 219215,
#  'followed': 4880,
#  'instructions': 1007,
#  'exactly': 4625,
#  'Im': 8330,
#  'one': 17615,
#  'those': 2419,
#  'food': 3498,
#  'combining': 78,
#  'diets': 45,
#  'left': 5064,
#  'out': 25697,
#  'white': 3690,
#  'wine': 1760,
#  'added': 22099,
#  'just': 25271,
#  'a': 166467,
#  'dash': 547,
#  'vinegar': 1946,
#  'instead': 11644,
#  'little': 16798,
#  'bit': 11153,
#  'not': 23840,
#  'enough': 5516,
#  'to': 132170,
#  'change': 4464,
#  'taste': 11290,
#  'dish': 9853,
#  'Super': 867,
#  'yummy': 5045,
#  'leftovers': 2318,
#  'lunch': 2501,
#  'today': 1915,
#  'lucky': 127,
#  'me': 10937,
#  'So': 4779,
#  'simple': 4911,
#  'tasty': 8112,
#  'used': 45538,
#  'yellow': 851,
#  'capsicum': 59,
#  'place': 2166,
#  'green': 4639,
#  'because': 11649,
#  'thats': 2027,
#  'what': 7676,
#  'had': 28047,
#  'hand': 3937,
#  'came': 5279,
#  'together': 5451,
#  'fast': 1387,
#  'Perfect': 1136,
#  'meal': 4348,
#  'if': 7448,
#  'you': 28143,
#  'dont': 7522,
#  'have': 35532,
#  'lot': 3905,
#  'time': 24744,
#  'Easy': 2302,
#  'healthy': 1854,
#  'Thanks': 32325,
#  'Stardustannie': 11,
#  'Made': 13439,
#  'PAC': 1827,
#  'Fall': 758,
#  'Very': 8891,
#  'nice': 9478,
#  'breakfast': 2266,
#  'HH': 7,
#  'easy': 21683,
#  'make': 37321,
#  'with': 59275,
#  'fresh': 8213,
#  'hot': 4172,
#  'coffe': 16,
#  'Instead': 908,
#  'toast': 703,
#  'served': 6550,
#  'by': 6670,
#  'Paula': 222,
#  'G': 44,
#  'that': 38949,
#  'made': 39363,
#  'earlier': 215,
#  'turned': 6379,
#  'great': 27326,
#  'will': 24097,
#  'be': 25514,
#  'regular': 3155,
#  'our': 6908,
#  'house': 2466,
#  'DH': 4114,
#  'loved': 13957,
#  'them': 25768,
#  'These': 8403,
#  'are': 15758,
#  'favorite': 3357,
#  'holidays': 340,
#  'children': 462,
#  'We': 12628,
#  'also': 15275,
#  'use': 17487,
#  'Rolo': 6,
#  'candies': 83,
#  'kisses': 84,
#  'Excellent': 2602,
#  'soup': 7150,
#  'The': 25845,
#  'tomato': 2427,
#  'flavor': 13426,
#  'this': 93873,
#  'freezer': 1329,
#  'tag': 1490,
#  'froze': 679,
#  'beautifully': 833,
#  'prepared': 1005,
#  'as': 35863,
#  'directed': 1353,
#  'then': 8692,
#  'allowed': 234,
#  'cool': 1160,
#  'container': 348,
#  'thawed': 283,
#  'fridge': 1463,
#  'reheated': 297,
#  'stovetop': 253,
#  'Worked': 253,
#  'perfectly': 1908,
#  'forgot': 1367,
#  'add': 13152,
#  'skim': 437,
#  'milk': 5487,
#  'still': 6783,
#  'tasted': 4443,
#  'pretty': 3762,
#  'good': 31181,
#  'Dancer': 72,
#  'dinner': 6102,
#  'excellent': 3167,
#  'finally': 543,
#  'found': 5203,
#  'tuna': 626,
#  'casserole': 1214,
#  'we': 13106,
#  'enjoy': 1480,
#  'thanks': 3937,
#  'When': 1641,
#  'snapped': 10,
#  'picture': 574,
#  'review': 1749,
#  'toasted': 837,
#  'pecans': 961,
#  'at': 15556,
#  'party': 1953,
#  'Prime': 23,
#  'Rib': 36,
#  'Ten': 16,
#  'stars': 3566,
#  'Lennie': 87,
#  'combination': 2276,
#  'flavors': 3266,
#  'reduce': 929,
#  'rice': 5454,
#  'cilantro': 1184,
#  'next': 10208,
#  'sharing': 11629,
#  'honKitten': 39,
#  'Oh': 1992,
#  'Bergy': 188,
#  'wonderful': 9253,
#  'cakes': 691,
#  'awesome': 2545,
#  'Fast': 158,
#  'put': 8603,
#  'get': 6853,
#  'fish': 1594,
#  'where': 997,
#  'live': 480,
#  'yuck': 26,
#  'am': 6321,
#  'tired': 165,
#  'trying': 1923,
#  'new': 2864,
#  'recipes': 4118,
#  'help': 918,
#  'lack': 181,
#  'quality': 492,
#  'But': 2905,
#  'problem': 1317,
#  'did': 18661,
#  'cloves': 1189,
#  'garlic': 8961,
#  'seasoned': 865,
#  'bread': 8116,
#  'crumbs': 1210,
#  'Smash': 3,
#  'Seasoning': 232,
#  'It': 19513,
#  'has': 4917,
#  'no': 6211,
#  'salt\r\nI': 6,
#  'tartar': 84,
#  'sauce': 16769,
#  'go': 4057,
#  '\r\nThank': 66,
#  'very': 26040,
#  'moist': 3831,
#  'cornbread': 529,
#  'two': 4806,
#  'days': 1168,
#  'later': 907,
#  'less': 3398,
#  'sugar': 9368,
#  'honey': 1834,
#  'farm': 84,
#  'butterand': 3,
#  'corn': 2728,
#  'about': 13225,
#  'ears': 59,
#  'Served': 1975,
#  'ribs': 1627,
#  'grill': 1288,
#  'Ive': 6503,
#  'been': 5841,
#  'making': 11171,
#  'past': 540,
#  'several': 1729,
#  'years': 2425,
#  'Its': 3661,
#  'always': 4249,
#  'extremely': 602,
#  'posting': 9924,
#  'generic': 34,
#  'sweetened': 261,
#  'condensed': 237,
#  'works': 893,
#  'well': 9879,
#  'tastes': 2832,
#  'costs': 20,
#  'usually': 1948,
#  'WalMart': 11,
#  'brand': 423,
#  'Exceptional': 15,
#  'delicious': 14634,
#  'really': 19695,
#  'liked': 5738,
#  'weekday': 73,
#  'leftover': 1936,
#  'looking': 3138,
#  'different': 4105,
#  'ways': 498,
#  'ground': 2519,
#  'beef': 3224,
#  'love': 9914,
#  'sandwich': 1316,
#  'alot': 596,
#  'sooo': 604,
#  'Lite': 33,
#  'brown': 3823,
#  'mustard': 1542,
#  'horse': 6,
#  'relish': 242,
#  'some': 21057,
#  'olives': 925,
#  'ons': 2,
#  'Next': 3516,
#  'balsamic': 529,
#  'dressingit': 3,
#  'mind': 483,
#  'cbreezie': 2,
#  'affordable': 33,
#  'addicting': 105,
#  'Our': 366,
#  'household': 157,
#  'Blessings': 8,
#  'chef': 414,
#  'never': 5019,
#  'apple': 1610,
#  'orange': 1778,
#  'juice': 3949,
#  'makes': 3372,
#  'all': 18010,
#  'difference': 1215,
#  'texture': 3618,
#  'wonderful\r\nThank': 4,
#  'You': 2450,
#  'were': 21189,
#  'grated': 977,
#  'cheddar': 1776,
#  'cheese': 11944,
#  'top': 6408,
#  'minutes': 8327,
#  'before': 8099,
#  'they': 17014,
#  'done': 2549,
#  'seasoning': 2861,
#  'best': 5295,
#  'pizza': 1250,
#  'dough': 3393,
#  'Other': 576,
#  'tried': 4747,
#  'machine': 760,
#  'way': 8213,
#  'too': 16024,
#  'sticky': 595,
#  'Leaving': 11,
#  'msg': 32,
#  'fine': 2128,
#  'divide': 63,
#  'half': 9003,
#  'knead': 106,
#  'floured': 90,
#  'surface': 96,
#  'few': 4934,
#  'times': 3323,
#  'stretch': 81,
#  'cirle': 1,
#  'like': 20964,
#  'bake': 2099,
#  'castiron': 25,
#  'skillet': 650,
#  'brush': 168,
#  'pan': 5518,
#  'olive': 2084,
#  'oil': 5607,
#  'sprinkle': 644,
#  'crust': 2487,
#  'lowest': 29,
#  'rack': 362,
#  'oven': 5135,
#  'saw': 752,
#  'Giada': 9,
#  'Today': 120,
#  'show': 212,
#  'last': 4600,
#  'month': 422,
#  'wanted': 2838,
#  'compare': 147,
#  'family': 8392,
#  'being': 1865,
#  'Marsala': 29,
#  'dry': 3015,
#  'red': 4608,
#  'chickenturkey': 4,
#  'sausage': 1639,
#  'cutting': 584,
#  'sausages': 149,
#  'finishing': 132,
#  'cooking': 5412,
#  'stove': 768,
#  'My': 14460,
#  'traditionally': 29,
#  'serves': 178,
#  'peppers': 2253,
#  'polentathis': 1,
#  'compared': 132,
#  'probably': 2736,
#  'calories': 679,
#  'heats': 11,
#  'kitchen': 800,
#  'summertime': 75,
#  'meatloaf': 605,
#  'took': 3867,
#  'reviewers': 889,
#  'suggestion': 619,
#  'another': 4903,
#  'crock': 1080,
#  'pot': 2565,
#  'sweet': 6989,
#  'tangy': 411,
#  'wonder': 276,
#  'addition': 2228,
#  'again': 21144,
#  'deliciously': 99,
#  'can': 9814,
#  'literally': 162,
#  'thrown': 106,
#  'soups': 338,
#  'i': 7877,
#  'ever': 4458,
#  'uncomplicated': 11,
#  'from': 12975,
#  'appealed': 21,
#  'simplicity': 213,
#  'quick': 4909,
#  'could': 6482,
#  'both': 2894,
#  'anything': 1780,
#  'see': 2343,
#  'more': 18338,
#  'substance': 25,
#  'nothing': 777,
#  'thankfully': 29,
#  'rustic': 49,
#  'roasted': 1303,
#  'balance': 454,
#  'other': 7203,
#  'ingredients': 6112,
#  'paul': 2,
#  'newman': 1,
#  'marinara': 133,
#  'cup': 8138,
#  'let': 2922,
#  'simmer': 447,
#  'would': 16822,
#  'definitly': 60,
#  'much': 15206,
#  'plus': 925,
#  'tea': 847,
#  'aroma': 369,
#  'steeping': 11,
#  'five': 713,
#  'large': 2229,
#  'glass': 659,
#  'ice': 1597,
#  'enjoyed': 7164,
#  'Good': 1692,
#  'marinade': 1474,
#  'Jack': 194,
#  'Daniels': 34,
#  'except': 2181,
#  'didnt': 16680,
#  'marinate': 390,
#  'quite': 3840,
#  'long': 2412,
#  'hours': 3234,
#  'grilled': 1304,
#  'counter': 188,
#  'everyone': 2770,
#  'Even': 1384,
#  'who': 3207,
#  'doesnt': 2209,
#  'dressed': 67,
#  'said': 3953,
#  'Almost': 109,
#  'teriyaki': 103,
#  'baked': 4392,
#  'potato': 2016,
#  'asparagus': 649,
#  'Fantastic': 799,
#  'earning': 2,
#  'raves': 144,
#  'table': 770,
#  'homegirl': 12,
#  'comforting': 228,
#  'lowsodium': 77,
#  'lowfat': 491,
#  'chicken': 13602,
#  'stock': 1189,
#  'butter': 7721,
#  'dried': 2404,
#  'parsley': 1216,
#  'do': 7567,
#  'than': 10347,
#  'an': 10577,
#  'hour': 1772,
#  'Me': 82,
#  'course': 892,
#  'Breezermom': 9,
#  'Market': 208,
#  'game': 1202,
#  'Will': 3440,
#  'kids': 3696,
#  'weekend': 746,
#  'your': 6423,
#  'cookies': 2942,
#  'already': 1785,
#  'Triple': 18,
#  'Chocolates': 2,
#  'Were': 143,
#  'addicted': 91,
#  'jam': 631,
#  'its': 7254,
#  'tend': 205,
#  'vinegarphobic': 1,
#  'adore': 109,
#  'black': 1664,
#  'pepper': 6580,
#  'increase': 510,
#  'Also': 3063,
#  'once': 1754,
#  'strawberries': 823,
#  'cook': 4881,
#  'down': 3702,
#  'masher': 53,
#  'break': 208,
#  'consistency': 980,
#  'kick': 1065,
#  'fun': 1140,
#  'English': 160,
#  'muffins': 1921,
#  'peanut': 1369,
#  'jelly': 403,
#  'sandwiches': 859,
#  'wheat': 1923,
#  'wish': 849,
#  'canning': 170,
#  'store': 1719,
#  'shelf': 63,
#  'started': 910,
#  'yesterday': 643,
#  'keep': 2191,
#  'back': 3647,
#  'coffee': 1326,
#  'figured': 258,
#  'might': 2856,
#  'along': 1634,
#  'benefits': 54,
#  'OK': 410,
#  'NEVER': 140,
#  'buy': 1231,
#  'jarred': 138,
#  'terrific': 806,
#  'early': 296,
#  'day': 4411,
#  'cant': 3569,
#  'wait': 2246,
#  'hint': 442,
#  'spice': 1783,
#  'omitted': 1634,
#  'flakes': 1254,
#  'small': 3266,
#  'tenderness': 48,
#  'rub': 489,
#  'right': 4670,
#  'cold': 1565,
#  'yogurt': 1437,
#  'whipped': 847,
#  'or': 12433,
#  'cumin': 893,
#  'curry': 935,
#  'cinnamon': 2763,
#  'try': 9694,
#  'Chinese': 218,
#  'resist': 120,
#  'splash': 307,
#  'squash': 803,
#  'microwave': 1234,
#  'minute': 740,
#  'blasts': 1,
#  'peel': 409,
#  'when': 9537,
#  'freeze': 891,
#  'flesh': 42,
#  'Carrots': 39,
#  'eaten': 1039,
#  'highly': 552,
#  'recommend': 1661,
#  'these': 16355,
#  'yet': 1551,
#  'treats': 178,
#  'plastic': 303,
#  'popsicle': 10,
#  'molds': 21,
#  'halved': 1315,
#  'popsicles': 7,
#  'They': 5948,
#  'adults': 281,
#  'gone': 1024,
#  'crazy': 437,
#  'eating': 2231,
#  'And': 2798,
#  'since': 4814,
#  'theyre': 505,
#  'Barb': 106,
#  'become': 735,
#  'modifications': 244,
#  'laziness': 14,
#  'semi': 81,
#  'breasts': 1414,
#  'browned': 778,
#  'rest': 2084,
#  'through': 1690,
#  'omit': 599,
#  'avoid': 199,
#  'sugaryness': 1,
#  'commented': 164,
#  'PERFECT': 248,
#  'As': 1555,
#  'couscous': 289,
#  'broth': 2831,
#  'soak': 339,
#  'margarine': 511,
#  'garlicbuttery': 1,
#  'certainly': 921,
#  'disappoint': 137,
#  'Miraklegirl': 10,
#  'fantastic': 2774,
#  'soft': 1696,
#  'chewy': 635,
#  'loveddd': 1,
#  'friends': 1426,
#  'chopped': 3307,
#  'mars': 2,
#  'bar': 318,
#  'chocolate': 5277,
#  'chips': 2744,
#  'worked': 3226,
#  'charm': 118,
#  'definitely': 6297,
#  'THANKS': 220,
#  'Christmas': 1590,
#  'Thank': 9766,
#  'treat': 1637,
#  'dressing': 3262,
#  'sesame': 660,
#  'seeds': 1233,
#  'lamb': 501,
#  'marinaded': 66,
#  'spices': 2145,
#  'simply': 752,
#  'WONDERFUL': 311,
#  'any': 6647,
#  'salt': 6443,
#  'substitution': 161,
#  'necessitydidnt': 1,
#  'hash': 174,
#  'browns': 143,
#  'potatoes': 5827,
#  'About': 76,
#  'peeked': 5,
#  'browning': 375,
#  'bottom': 1305,
#  'werent': 578,
#  'needed': 3038,
#  'water': 5337,
#  'DUH': 3,
#  'remember': 678,
#  'how': 5295,
#  'Ill': 5991,
#  'redo': 10,
#  'die': 416,
#  'truly': 633,
#  'give': 3314,
#  'againbrbrI': 4,
#  'drumsticks': 87,
#  'wings': 603,
#  'grocery': 461,
#  'low': 2640,
#  'sodium': 541,
#  'soy': 1230,
#  'forget': 255,
#  'know': 3853,
#  'affected': 68,
#  'thicker': 525,
#  'barbecue': 230,
#  'move': 92,
#  'fluid': 35,
#  'thicken': 787,
#  'starch': 258,
#  'flour': 5100,
#  'stated': 940,
#  'mom': 897,
#  'Northern': 39,
#  'Ireland': 21,
#  'introduced': 38,
#  'Marmite': 13,
#  'age': 64,
#  'rye': 170,
#  'marmite': 9,
#  'dip': 1467,
#  'eggs': 2170,
#  'Paulas': 16,
#  'Peach': 24,
#  'Dump': 9,
#  'Cake': 276,
#  'forward': 800,
#  'her': 1498,
#  'call': 580,
#  'future': 793,
#  'dessert': 1811,
#  'fix': 557,
#  'short': 504,
#  'notice': 192,
#  'Wow': 1795,
#  'What': 2609,
#  'amazing': 2470,
#  'stuff': 1401,
#  'Hokey': 4,
#  'Pokey': 6,
#  'icecream': 99,
#  'this\nI': 5,
#  'shocked': 69,
#  'complete': 265,
#  'colour': 187,
#  'after': 5843,
#  'stirring': 264,
#  'baking': 3927,
#  'soda': 449,
#  'quick\nI': 1,
#  'burned': 244,
#  'ours': 310,
#  'difficult': 418,
#  'spread': 1280,
#  'flat': 430,
#  'first': 6857,
#  'go\nNext': 1,
#  'whats': 148,
#  'come': 1668,
#  'manual': 11,
#  'method': 846,
#  'directions': 1937,
#  'follow': 1060,
#  'produced': 157,
#  'results': 1273,
#  'light': 3078,
#  'zaatar': 20,
#  'topping': 2087,
#  'keeper': 4585,
#  'Best': 702,
#  'event': 292,
#  'recommended': 537,
#  'awalde': 11,
#  'sorry': 708,
#  'wasnt': 3289,
#  'There': 1143,
#  'something': 4246,
#  'missing': 651,
#  'turn': 1194,
#  'turmeric': 94,
#  'strange': 164,
#  'color': 1031,
#  'unappealing': 20,
#  'smelled': 722,
#  'carne': 7,
#  'asada': 6,
#  'maybe': 2359,
#  'expecting': 363,
#  'cooked': 6945,
#  'delightful': 406,
#  'while': 3327,
#  'grilling': 335,
#  'meet': 58,
#  'expectations': 95,
#  'watching': 234,
#  'think': 11026,
#  'tweak': 212,
#  'sure': 6410,
#  'Did': 460,
#  'microwaved': 190,
#  'spuds': 49,
#  'onions': 4043,
#  'night': 3696,
#  'onion': 5486,
#  'each': 2447,
#  'their': 1560,
#  'flavours': 658,
#  'distinctly\r\nGood': 1,
#  'veggie': 718,
#  'Lovely': 407,
#  'beautiful': 1006,
#  'Thanksgiving': 862,
#  'morning': 1650,
#  'With': 671,
#  'link': 51,
#  'sliced': 2177,
#  'fruit': 1367,
#  'visiting': 128,
#  'grands': 7,
#  'Kittencal': 685,
#  'teach': 25,
#  'high': 1486,
#  'school': 442,
#  'foods': 328,
#  'class': 142,
#  'studying': 10,
#  'legumes': 6,
#  'sour': 2648,
#  'cream': 9349,
#  'Tobasco': 27,
#  'tortilla': 590,
#  'While': 419,
#  'students': 48,
#  'look': 1591,
#  'Not': 1866,
#  'single': 372,
#  'student': 53,
#  'disliked': 21,
#  'starting': 258,
#  'period': 68,
#  'reheating': 67,
#  'Many': 187,
#  'requested': 375,
#  'second': 1699,
#  'copy': 174,
#  'take': 2333,
#  'home': 2245,
#  'Great': 5961,
#  'job': 238,
#  'definately': 1075,
#  'lemon': 4220,
#  'zest': 806,
#  'devine': 48,
#  'reheat': 181,
#  'crunchiness': 42,
#  'which': 8103,
#  'scone': 128,
#  'cranberries': 650,
#  'YummoBe': 1,
#  'heaps': 43,
#  'now': 5053,
#  'recipe\r\n': 48,
#  'momaphet': 13,
#  's': 282,
#  'ridiculously': 37,
#  'crisp': 966,
#  'sitting': 367,
#  'here': 2925,
#  'wishing': 41,
#  'batch': 2693,
#  'got': 4187,
#  'blasting': 2,
#  'coconut': 1690,
#  'Just': 2362,
#  'dh': 297,
#  'wont': 1285,
#  'gems': 49,
#  'box': 743,
#  'Culinary': 129,
#  'Quest': 125,
#  'Suitcase': 16,
#  'Gourmets': 27,
#  'quartered': 165,
#  'easily': 1048,
#  'Sarah': 42,
#  'Well': 1100,
#  'us': 3811,
#  'scarfed': 60,
#  'avocado': 434,
#  'finely': 532,
#  'fat': 3345,
#  'philadelphia': 2,
#  'base': 790,
#  'dolloped': 5,
#  'does': 1838,
#  'melt': 546,
#  'TFC': 3,
#  'Make': 472,
#  'Recipe': 2615,
#  'edition': 14,
#  'Delicious': 3268,
#  'Doesnt': 57,
#  'canes': 24,
#  'At': 452,
#  'Too': 240,
#  'mayo': 1034,
#  'Having': 133,
#  'lots': 1190,
#  'MENORCA': 1,
#  'rind': 168,
#  'find': 3593,
#  'may': 2495,
#  'round': 666,
#  'loose': 111,
#  'tin': 369,
#  'Almond': 64,
#  'rapberries': 1,
#  'themits': 1,
#  'winner': 1327,
#  'everytime': 101,
#  'needs': 853,
#  'tweaked': 165,
#  'spicier': 120,
#  'taco': 476,
#  'homemade': 1626,
#  'Straightforward': 2,
#  'adding': 3908,
#  'guacamole': 153,
#  'finish': 511,
#  'bite': 1107,
#  'A': 5828,
#  'square': 203,
#  'super': 1993,
#  'many': 3212,
#  'shine': 63,
#  'Moist': 182,
#  'flavorful': 2091,
#  'under': 697,
#  'skin': 691,
#  'rosemary': 874,
#  'basil': 1525,
#  'overwhelming': 174,
#  'Really': 1624,
#  'blend': 1417,
#  'thighs': 646,
#  'sooner': 81,
#  'Summer': 105,
#  'Comfort': 210,
#  'Cafe': 145,
#  'Followed': 619,
#  'tee': 86,
#  'fell': 465,
#  'middle': 640,
#  'during': 990,
#  'wasted': 78,
#  'money': 192,
#  'garbage': 37,
#  'DELICIOUS': 497,
#  'touch': 1067,
#  'Sounds': 88,
#  'although': 1252,
#  'replace': 253,
#  'cucumber': 382,
#  'hate': 404,
#  'lol': 745,
#  'pickles': 211,
#  'reason': 644,
#  'NO': 185,
#  'IDEA': 8,
#  'convert': 57,
#  'grams': 153,
#  'normal': 346,
#  'measurements': 259,
#  'Hey': 142,
#  'guys': 195,
#  'why': 1063,
#  'option': 321,
#  'Everyone': 1884,
#  'salad': 5496,
#  'roll': 978,
#  'Probably': 158,
#  'should': 2258,
#  'Miss': 264,
#  'Lillie': 1,
#  'Kauitzsch': 1,
#  'proud': 95,
#  'If': 2364,
#  'amp': 1090,
#  'powder': 3957,
#  'timemight': 1,
#  'bell': 812,
#  'heard': 279,
#  'frosting': 1782,
#  'Penzys': 9,
#  'Dark': 101,
#  'Cocoa': 50,
#  'On': 267,
#  'poster': 94,
#  'TBSP': 90,
#  'syrup': 1650,
#  'glossy': 22,
#  'Be': 259,
#  'sift': 34,
#  'double': 1947,
#  'layer': 952,
#  'cake': 6951,
#  'received': 346,
#  'requests': 224,
#  'amazed': 141,
#  'Plus': 199,
#  'freezes': 144,
#  'check': 219,
#  'Since': 842,
#  'drink': 1448,
#  'most': 2338,
#  'everyday': 148,
#  ...}

# %% [markdown]
# ## Numba

# %%
import json

# %% [markdown]
# В файле `rating_predictions.json` хранятся данные о рейтингах рецептов и прогнозных значениях рейтингов для этого рецепта, полученных при помощи модели машинного обучения.
#
# Напишите несколько версий функции (см. [MAPE](https://en.wikipedia.org/wiki/Mean_absolute_percentage_error)) для расчета среднего абсолютного процентного отклонения значения рейтинга отзыва на рецепт от прогнозного значения рейтинга для данного рецепта.
#
#
# Замечание 1: в формуле MAPE под $A_t$ понимается рейтинг из отзыва $t$, под $F_t$ - прогнозное значения рейтинга отзыва $t$.
#
# Замечание 2: в результате работы функций должно получиться одно число - MAPE для всего набора данных.

# %%
f =json.load(open('rating_predictions.json'))
f
# Out:
# [{'rating': 5.0, 'prediction': 4.944444444444445},
#  {'rating': 5.0, 'prediction': 4.4375},
#  {'rating': 5.0, 'prediction': 4.7272727272727275},
#  {'rating': 5.0, 'prediction': 4.3545454545454545},
#  {'rating': 5.0, 'prediction': 4.888888888888889},
#  {'rating': 5.0, 'prediction': 4.4855072463768115},
#  {'rating': 3.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.594936708860759},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.4},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 3.6666666666666665},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 4.0, 'prediction': 4.403381642512077},
#  {'rating': 2.0, 'prediction': 3.5},
#  {'rating': 4.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 3.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.090909090909091},
#  {'rating': 5.0, 'prediction': 4.5625},
#  {'rating': 5.0, 'prediction': 3.5714285714285716},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 4.871428571428571},
#  {'rating': 4.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.625},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.5372750642673525},
#  {'rating': 5.0, 'prediction': 4.553488372093023},
#  {'rating': 5.0, 'prediction': 4.380952380952381},
#  {'rating': 3.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.680851063829787},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.299703264094956},
#  {'rating': 4.0, 'prediction': 3.909090909090909},
#  {'rating': 5.0, 'prediction': 4.764705882352941},
#  {'rating': 4.0, 'prediction': 4.741935483870968},
#  {'rating': 5.0, 'prediction': 4.587962962962963},
#  {'rating': 5.0, 'prediction': 4.327402135231317},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.857142857142857},
#  {'rating': 5.0, 'prediction': 4.6568627450980395},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.625},
#  {'rating': 5.0, 'prediction': 3.75},
#  {'rating': 3.0, 'prediction': 3.5},
#  {'rating': 5.0, 'prediction': 4.322314049586777},
#  {'rating': 3.0, 'prediction': 4.2},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.739130434782608},
#  {'rating': 4.0, 'prediction': 2.7},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.2771345875542695},
#  {'rating': 5.0, 'prediction': 4.587962962962963},
#  {'rating': 2.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.109090909090909},
#  {'rating': 4.0, 'prediction': 4.3545454545454545},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.689655172413793},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.828947368421052},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.235294117647059},
#  {'rating': 5.0, 'prediction': 4.377777777777778},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.923076923076923},
#  {'rating': 5.0, 'prediction': 4.574257425742574},
#  {'rating': 4.0, 'prediction': 3.935483870967742},
#  {'rating': 4.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.6},
#  {'rating': 5.0, 'prediction': 4.862068965517241},
#  {'rating': 5.0, 'prediction': 4.5372750642673525},
#  {'rating': 1.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.918918918918919},
#  {'rating': 5.0, 'prediction': 4.714285714285714},
#  {'rating': 5.0, 'prediction': 4.322709163346613},
#  {'rating': 5.0, 'prediction': 4.222222222222222},
#  {'rating': 5.0, 'prediction': 4.428571428571429},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 1.0, 'prediction': 1.0},
#  {'rating': 4.0, 'prediction': 3.8},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.541666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 3.0, 'prediction': 4.518518518518518},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 1.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.614406779661017},
#  {'rating': 1.0, 'prediction': 4.358208955223881},
#  {'rating': 5.0, 'prediction': 4.6},
#  {'rating': 4.0, 'prediction': 4.714285714285714},
#  {'rating': 4.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 4.428571428571429},
#  {'rating': 5.0, 'prediction': 4.413793103448276},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 3.0, 'prediction': 2.6666666666666665},
#  {'rating': 5.0, 'prediction': 4.608695652173913},
#  {'rating': 5.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 4.804878048780488},
#  {'rating': 5.0, 'prediction': 4.857142857142857},
#  {'rating': 5.0, 'prediction': 4.487719298245614},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.6666666666666665},
#  {'rating': 4.0, 'prediction': 4.533333333333333},
#  {'rating': 5.0, 'prediction': 4.487719298245614},
#  {'rating': 5.0, 'prediction': 4.688524590163935},
#  {'rating': 5.0, 'prediction': 4.13986013986014},
#  {'rating': 5.0, 'prediction': 4.538461538461538},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.466666666666667},
#  {'rating': 5.0, 'prediction': 4.625},
#  {'rating': 5.0, 'prediction': 4.521739130434782},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.0606060606060606},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.760869565217392},
#  {'rating': 5.0, 'prediction': 4.857142857142857},
#  {'rating': 5.0, 'prediction': 4.7272727272727275},
#  {'rating': 4.0, 'prediction': 4.6},
#  {'rating': 5.0, 'prediction': 4.357142857142857},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.275862068965517},
#  {'rating': 1.0, 'prediction': 1.0},
#  {'rating': 5.0, 'prediction': 4.575},
#  {'rating': 5.0, 'prediction': 4.363636363636363},
#  {'rating': 5.0, 'prediction': 4.857142857142857},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.408239700374532},
#  {'rating': 5.0, 'prediction': 4.391304347826087},
#  {'rating': 5.0, 'prediction': 4.6923076923076925},
#  {'rating': 5.0, 'prediction': 4.4222222222222225},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.739130434782608},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 4.688888888888889},
#  {'rating': 5.0, 'prediction': 4.172413793103448},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.7272727272727275},
#  {'rating': 4.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 4.2},
#  {'rating': 4.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 4.13986013986014},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.0476190476190474},
#  {'rating': 5.0, 'prediction': 4.875},
#  {'rating': 5.0, 'prediction': 4.446043165467626},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 3.0, 'prediction': 3.5714285714285716},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.538461538461538},
#  {'rating': 4.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 4.166666666666667},
#  {'rating': 5.0, 'prediction': 3.772727272727273},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.470588235294118},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.444444444444445},
#  {'rating': 5.0, 'prediction': 3.9047619047619047},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.6444444444444444},
#  {'rating': 3.0, 'prediction': 4.714285714285714},
#  {'rating': 4.0, 'prediction': 4.435185185185185},
#  {'rating': 4.0, 'prediction': 3.3333333333333335},
#  {'rating': 5.0, 'prediction': 4.96969696969697},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.8},
#  {'rating': 5.0, 'prediction': 3.289473684210526},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.657608695652174},
#  {'rating': 5.0, 'prediction': 4.5588235294117645},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.577540106951871},
#  {'rating': 5.0, 'prediction': 4.266666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.888888888888889},
#  {'rating': 5.0, 'prediction': 3.769230769230769},
#  {'rating': 5.0, 'prediction': 4.882352941176471},
#  {'rating': 5.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.551724137931035},
#  {'rating': 5.0, 'prediction': 4.444444444444445},
#  {'rating': 4.0, 'prediction': 4.181818181818182},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.315789473684211},
#  {'rating': 5.0, 'prediction': 4.142857142857143},
#  {'rating': 5.0, 'prediction': 4.741935483870968},
#  {'rating': 5.0, 'prediction': 4.636363636363637},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 4.0, 'prediction': 4.777777777777778},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.818181818181818},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.588785046728972},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 4.0, 'prediction': 4.413793103448276},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.3},
#  {'rating': 5.0, 'prediction': 4.339622641509434},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.6923076923076925},
#  {'rating': 5.0, 'prediction': 4.888888888888889},
#  {'rating': 3.0, 'prediction': 4.333333333333333},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.818181818181818},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.222222222222222},
#  {'rating': 5.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 4.688888888888889},
#  {'rating': 5.0, 'prediction': 4.391304347826087},
#  {'rating': 5.0, 'prediction': 4.444444444444445},
#  {'rating': 4.0, 'prediction': 4.166666666666667},
#  {'rating': 5.0, 'prediction': 4.435185185185185},
#  {'rating': 5.0, 'prediction': 4.285714285714286},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 4.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 4.944444444444445},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.446043165467626},
#  {'rating': 5.0, 'prediction': 4.331081081081081},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.6875},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.916666666666667},
#  {'rating': 5.0, 'prediction': 4.4},
#  {'rating': 5.0, 'prediction': 3.8},
#  {'rating': 5.0, 'prediction': 3.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.331081081081081},
#  {'rating': 5.0, 'prediction': 4.478448275862069},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 4.104938271604938},
#  {'rating': 4.0, 'prediction': 4.6},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.380952380952381},
#  {'rating': 5.0, 'prediction': 4.2771345875542695},
#  {'rating': 5.0, 'prediction': 4.551724137931035},
#  {'rating': 5.0, 'prediction': 4.9},
#  {'rating': 4.0, 'prediction': 3.875},
#  {'rating': 5.0, 'prediction': 4.571428571428571},
#  {'rating': 5.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.9},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.6875},
#  {'rating': 5.0, 'prediction': 4.511904761904762},
#  {'rating': 5.0, 'prediction': 4.637362637362638},
#  {'rating': 5.0, 'prediction': 2.75},
#  {'rating': 5.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 3.9565217391304346},
#  {'rating': 5.0, 'prediction': 4.614406779661017},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.57},
#  {'rating': 5.0, 'prediction': 4.684210526315789},
#  {'rating': 5.0, 'prediction': 4.6},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.609756097560975},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 3.3684210526315788},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.60377358490566},
#  {'rating': 5.0, 'prediction': 4.7},
#  {'rating': 4.0, 'prediction': 3.3333333333333335},
#  {'rating': 5.0, 'prediction': 4.3},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.520833333333333},
#  {'rating': 5.0, 'prediction': 4.2388059701492535},
#  {'rating': 5.0, 'prediction': 4.714285714285714},
#  {'rating': 5.0, 'prediction': 4.551724137931035},
#  {'rating': 5.0, 'prediction': 4.403381642512077},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.935483870967742},
#  {'rating': 5.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 4.645161290322581},
#  {'rating': 3.0, 'prediction': 3.3333333333333335},
#  {'rating': 5.0, 'prediction': 4.6923076923076925},
#  {'rating': 5.0, 'prediction': 4.12},
#  {'rating': 5.0, 'prediction': 4.657608695652174},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 3.7027027027027026},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.551724137931035},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 3.0, 'prediction': 4.7},
#  {'rating': 4.0, 'prediction': 3.8846153846153846},
#  {'rating': 4.0, 'prediction': 4.833333333333333},
#  {'rating': 2.0, 'prediction': 2.0},
#  {'rating': 4.0, 'prediction': 4.333333333333333},
#  {'rating': 4.0, 'prediction': 3.4285714285714284},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 4.144927536231884},
#  {'rating': 5.0, 'prediction': 4.928571428571429},
#  {'rating': 4.0, 'prediction': 3.8333333333333335},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 3.801418439716312},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.416666666666667},
#  {'rating': 5.0, 'prediction': 4.57},
#  {'rating': 5.0, 'prediction': 4.2},
#  {'rating': 5.0, 'prediction': 4.487719298245614},
#  {'rating': 5.0, 'prediction': 4.260869565217392},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.2771345875542695},
#  {'rating': 5.0, 'prediction': 4.896551724137931},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.487719298245614},
#  {'rating': 5.0, 'prediction': 4.587155963302752},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.3333333333333335},
#  {'rating': 4.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 4.104938271604938},
#  {'rating': 5.0, 'prediction': 3.3333333333333335},
#  {'rating': 5.0, 'prediction': 4.090909090909091},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 3.923076923076923},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 2.6},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 3.6296296296296298},
#  {'rating': 5.0, 'prediction': 4.490196078431373},
#  {'rating': 1.0, 'prediction': 3.0},
#  {'rating': 5.0, 'prediction': 3.7291666666666665},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.95},
#  {'rating': 5.0, 'prediction': 4.529411764705882},
#  {'rating': 5.0, 'prediction': 4.516129032258065},
#  {'rating': 4.0, 'prediction': 4.555555555555555},
#  {'rating': 3.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.153846153846154},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.35},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 3.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 4.638888888888889},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 4.842105263157895},
#  {'rating': 5.0, 'prediction': 4.446043165467626},
#  {'rating': 4.0, 'prediction': 4.444444444444445},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.521739130434782},
#  {'rating': 4.0, 'prediction': 4.076923076923077},
#  {'rating': 4.0, 'prediction': 4.529411764705882},
#  {'rating': 5.0, 'prediction': 3.6},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.625},
#  {'rating': 5.0, 'prediction': 4.482758620689655},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.625},
#  {'rating': 5.0, 'prediction': 4.5625},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.6},
#  {'rating': 5.0, 'prediction': 4.355140186915888},
#  {'rating': 4.0, 'prediction': 4.909090909090909},
#  {'rating': 5.0, 'prediction': 4.888888888888889},
#  {'rating': 4.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 1.0, 'prediction': 4.384615384615385},
#  {'rating': 5.0, 'prediction': 3.8333333333333335},
#  {'rating': 2.0, 'prediction': 2.3333333333333335},
#  {'rating': 4.0, 'prediction': 4.8},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.211538461538462},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.25},
#  {'rating': 4.0, 'prediction': 4.125},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.571428571428571},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 3.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.796296296296297},
#  {'rating': 5.0, 'prediction': 4.56043956043956},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 2.0, 'prediction': 2.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.857142857142857},
#  {'rating': 5.0, 'prediction': 4.589743589743589},
#  {'rating': 5.0, 'prediction': 4.614406779661017},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.461538461538462},
#  {'rating': 4.0, 'prediction': 4.577540106951871},
#  {'rating': 3.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.235294117647059},
#  {'rating': 5.0, 'prediction': 4.0476190476190474},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.837209302325581},
#  {'rating': 5.0, 'prediction': 4.9},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.671875},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.6923076923076925},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 2.0, 'prediction': 4.567164179104478},
#  {'rating': 5.0, 'prediction': 4.329268292682927},
#  {'rating': 5.0, 'prediction': 4.571428571428571},
#  {'rating': 5.0, 'prediction': 3.6470588235294117},
#  {'rating': 5.0, 'prediction': 4.827160493827161},
#  {'rating': 5.0, 'prediction': 4.51685393258427},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.785714285714286},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.8125},
#  {'rating': 5.0, 'prediction': 4.976190476190476},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.496},
#  {'rating': 5.0, 'prediction': 4.642857142857143},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.697986577181208},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.170731707317073},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.37037037037037},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.8},
#  {'rating': 4.0, 'prediction': 4.153846153846154},
#  {'rating': 5.0, 'prediction': 4.520833333333333},
#  {'rating': 5.0, 'prediction': 4.636363636363637},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.05},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.6666666666666665},
#  {'rating': 5.0, 'prediction': 4.884615384615385},
#  {'rating': 1.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.57},
#  {'rating': 5.0, 'prediction': 4.3},
#  {'rating': 4.0, 'prediction': 4.3125},
#  {'rating': 5.0, 'prediction': 4.884615384615385},
#  {'rating': 5.0, 'prediction': 4.527272727272727},
#  {'rating': 4.0, 'prediction': 4.564516129032258},
#  {'rating': 5.0, 'prediction': 4.647058823529412},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 4.116504854368932},
#  {'rating': 4.0, 'prediction': 4.870588235294117},
#  {'rating': 5.0, 'prediction': 4.454545454545454},
#  {'rating': 4.0, 'prediction': 4.583333333333333},
#  {'rating': 5.0, 'prediction': 4.538461538461538},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 4.0, 'prediction': 4.857142857142857},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 3.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.9565217391304346},
#  {'rating': 4.0, 'prediction': 4.166666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.4855072463768115},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.444444444444445},
#  {'rating': 5.0, 'prediction': 4.617021276595745},
#  {'rating': 5.0, 'prediction': 4.875},
#  {'rating': 5.0, 'prediction': 4.446153846153846},
#  {'rating': 5.0, 'prediction': 4.469387755102041},
#  {'rating': 5.0, 'prediction': 4.553488372093023},
#  {'rating': 5.0, 'prediction': 4.428571428571429},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.0},
#  {'rating': 5.0, 'prediction': 3.75},
#  {'rating': 5.0, 'prediction': 4.7272727272727275},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.237704918032787},
#  {'rating': 5.0, 'prediction': 4.916666666666667},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 3.3333333333333335},
#  {'rating': 5.0, 'prediction': 4.327402135231317},
#  {'rating': 5.0, 'prediction': 3.801418439716312},
#  {'rating': 5.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.537366548042705},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.260869565217392},
#  {'rating': 5.0, 'prediction': 4.485714285714286},
#  {'rating': 5.0, 'prediction': 3.3333333333333335},
#  {'rating': 5.0, 'prediction': 3.6444444444444444},
#  {'rating': 4.0, 'prediction': 4.333333333333333},
#  {'rating': 3.0, 'prediction': 3.75},
#  {'rating': 2.0, 'prediction': 4.490196078431373},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 4.64},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 3.8666666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.552173913043478},
#  {'rating': 4.0, 'prediction': 4.680851063829787},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.857142857142857},
#  {'rating': 5.0, 'prediction': 4.444444444444445},
#  {'rating': 5.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.233333333333333},
#  {'rating': 5.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 4.758620689655173},
#  {'rating': 5.0, 'prediction': 4.636363636363637},
#  {'rating': 5.0, 'prediction': 3.7916666666666665},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 1.0, 'prediction': 3.5},
#  {'rating': 5.0, 'prediction': 4.446043165467626},
#  {'rating': 5.0, 'prediction': 4.57},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.222222222222222},
#  {'rating': 4.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 4.760869565217392},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.166666666666667},
#  {'rating': 5.0, 'prediction': 4.833333333333333},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 3.0, 'prediction': 4.6},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.828947368421052},
#  {'rating': 4.0, 'prediction': 4.884615384615385},
#  {'rating': 4.0, 'prediction': 4.684210526315789},
#  {'rating': 5.0, 'prediction': 4.51685393258427},
#  {'rating': 5.0, 'prediction': 4.543478260869565},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.2631578947368425},
#  {'rating': 5.0, 'prediction': 4.46067415730337},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 4.0, 'prediction': 4.875},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 2.0, 'prediction': 4.327402135231317},
#  {'rating': 5.0, 'prediction': 4.116504854368932},
#  {'rating': 5.0, 'prediction': 4.688888888888889},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 2.0, 'prediction': 4.148936170212766},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.235294117647059},
#  {'rating': 4.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 3.0, 'prediction': 3.0},
#  {'rating': 5.0, 'prediction': 4.142857142857143},
#  {'rating': 4.0, 'prediction': 4.2727272727272725},
#  {'rating': 5.0, 'prediction': 4.246153846153846},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.166666666666667},
#  {'rating': 5.0, 'prediction': 4.529411764705882},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.5372750642673525},
#  {'rating': 5.0, 'prediction': 4.2303030303030305},
#  {'rating': 5.0, 'prediction': 4.745341614906832},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.3333333333333335},
#  {'rating': 5.0, 'prediction': 3.8461538461538463},
#  {'rating': 5.0, 'prediction': 3.7966101694915255},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.22804054054054},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.95},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 3.0, 'prediction': 3.0},
#  {'rating': 4.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 4.625},
#  {'rating': 5.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.46},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.6},
#  {'rating': 5.0, 'prediction': 3.0},
#  {'rating': 5.0, 'prediction': 4.551724137931035},
#  {'rating': 5.0, 'prediction': 4.6},
#  {'rating': 4.0, 'prediction': 3.3333333333333335},
#  {'rating': 5.0, 'prediction': 4.3545454545454545},
#  {'rating': 5.0, 'prediction': 4.6875},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.523809523809524},
#  {'rating': 5.0, 'prediction': 4.496},
#  {'rating': 5.0, 'prediction': 4.571428571428571},
#  {'rating': 5.0, 'prediction': 3.8125},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.6},
#  {'rating': 5.0, 'prediction': 4.142857142857143},
#  {'rating': 5.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.271317829457364},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 1.0, 'prediction': 3.5555555555555554},
#  {'rating': 4.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.857142857142857},
#  {'rating': 4.0, 'prediction': 4.403381642512077},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.888888888888889},
#  {'rating': 5.0, 'prediction': 4.6},
#  {'rating': 4.0, 'prediction': 4.347368421052631},
#  {'rating': 4.0, 'prediction': 4.496},
#  {'rating': 4.0, 'prediction': 3.735294117647059},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.491525423728813},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.555555555555555},
#  {'rating': 5.0, 'prediction': 4.13986013986014},
#  {'rating': 5.0, 'prediction': 4.5588235294117645},
#  {'rating': 5.0, 'prediction': 4.307392996108949},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.299703264094956},
#  {'rating': 5.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 4.823529411764706},
#  {'rating': 2.0, 'prediction': 2.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.3125},
#  {'rating': 4.0, 'prediction': 4.260869565217392},
#  {'rating': 5.0, 'prediction': 4.818181818181818},
#  {'rating': 5.0, 'prediction': 4.13986013986014},
#  {'rating': 5.0, 'prediction': 4.769230769230769},
#  {'rating': 5.0, 'prediction': 4.916666666666667},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.25},
#  {'rating': 3.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 3.3333333333333335},
#  {'rating': 4.0, 'prediction': 4.833333333333333},
#  {'rating': 4.0, 'prediction': 3.825925925925926},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 4.22804054054054},
#  {'rating': 5.0, 'prediction': 4.903225806451613},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.403381642512077},
#  {'rating': 5.0, 'prediction': 4.0675675675675675},
#  {'rating': 5.0, 'prediction': 4.052631578947368},
#  {'rating': 5.0, 'prediction': 3.484848484848485},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.875},
#  {'rating': 5.0, 'prediction': 4.918918918918919},
#  {'rating': 5.0, 'prediction': 3.4},
#  {'rating': 3.0, 'prediction': 4.235294117647059},
#  {'rating': 5.0, 'prediction': 4.521739130434782},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 3.8},
#  {'rating': 5.0, 'prediction': 4.614406779661017},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.827586206896552},
#  {'rating': 5.0, 'prediction': 4.375},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 3.0, 'prediction': 4.5625},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.375},
#  {'rating': 5.0, 'prediction': 3.6666666666666665},
#  {'rating': 5.0, 'prediction': 4.7272727272727275},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.071428571428571},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 3.0, 'prediction': 3.825925925925926},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 4.643478260869565},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 4.661971830985915},
#  {'rating': 5.0, 'prediction': 4.587962962962963},
#  {'rating': 5.0, 'prediction': 4.283018867924528},
#  {'rating': 4.0, 'prediction': 3.3333333333333335},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.7272727272727275},
#  {'rating': 5.0, 'prediction': 4.818181818181818},
#  {'rating': 4.0, 'prediction': 3.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 1.0, 'prediction': 4.2303030303030305},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.5},
#  {'rating': 5.0, 'prediction': 4.2},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.408239700374532},
#  {'rating': 4.0, 'prediction': 4.348837209302325},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.636363636363637},
#  {'rating': 5.0, 'prediction': 4.527272727272727},
#  {'rating': 4.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 4.2771345875542695},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 1.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 4.695652173913044},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.478448275862069},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.875},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.609756097560975},
#  {'rating': 2.0, 'prediction': 2.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.537366548042705},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.5372750642673525},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.53125},
#  {'rating': 4.0, 'prediction': 3.25},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 4.951219512195122},
#  {'rating': 5.0, 'prediction': 4.322709163346613},
#  {'rating': 5.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 4.714285714285714},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 3.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 2.5},
#  {'rating': 5.0, 'prediction': 4.7272727272727275},
#  {'rating': 3.0, 'prediction': 3.0},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.555555555555555},
#  {'rating': 5.0, 'prediction': 4.857142857142857},
#  {'rating': 5.0, 'prediction': 4.283018867924528},
#  {'rating': 5.0, 'prediction': 4.6875},
#  {'rating': 4.0, 'prediction': 4.6440677966101696},
#  {'rating': 5.0, 'prediction': 4.37948717948718},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.230769230769231},
#  {'rating': 5.0, 'prediction': 4.277777777777778},
#  {'rating': 5.0, 'prediction': 4.676470588235294},
#  {'rating': 4.0, 'prediction': 4.470588235294118},
#  {'rating': 5.0, 'prediction': 4.7560975609756095},
#  {'rating': 4.0, 'prediction': 4.722222222222222},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.75},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.245283018867925},
#  {'rating': 5.0, 'prediction': 4.418181818181818},
#  {'rating': 5.0, 'prediction': 4.875},
#  {'rating': 5.0, 'prediction': 3.8461538461538463},
#  {'rating': 5.0, 'prediction': 4.818181818181818},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 3.0, 'prediction': 3.6666666666666665},
#  {'rating': 3.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.586705202312139},
#  {'rating': 5.0, 'prediction': 4.909090909090909},
#  {'rating': 5.0, 'prediction': 4.380952380952381},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.416666666666667},
#  {'rating': 5.0, 'prediction': 4.424242424242424},
#  {'rating': 2.0, 'prediction': 4.57},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.290697674418604},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 3.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.857142857142857},
#  {'rating': 5.0, 'prediction': 4.657608695652174},
#  {'rating': 3.0, 'prediction': 4.357142857142857},
#  {'rating': 5.0, 'prediction': 4.104938271604938},
#  {'rating': 5.0, 'prediction': 4.331081081081081},
#  {'rating': 5.0, 'prediction': 4.809523809523809},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.8333333333333335},
#  {'rating': 5.0, 'prediction': 4.537366548042705},
#  {'rating': 4.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 4.761904761904762},
#  {'rating': 5.0, 'prediction': 3.75},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 4.589743589743589},
#  {'rating': 3.0, 'prediction': 4.032258064516129},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.615384615384615},
#  {'rating': 5.0, 'prediction': 4.299703264094956},
#  {'rating': 3.0, 'prediction': 3.0},
#  {'rating': 4.0, 'prediction': 4.555555555555555},
#  {'rating': 5.0, 'prediction': 4.902777777777778},
#  {'rating': 4.0, 'prediction': 4.818181818181818},
#  {'rating': 2.0, 'prediction': 2.6},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.875},
#  {'rating': 5.0, 'prediction': 4.421686746987952},
#  {'rating': 5.0, 'prediction': 4.653846153846154},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.2771345875542695},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.4},
#  {'rating': 5.0, 'prediction': 4.831325301204819},
#  {'rating': 5.0, 'prediction': 4.6},
#  {'rating': 5.0, 'prediction': 4.408239700374532},
#  {'rating': 5.0, 'prediction': 4.142857142857143},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.833333333333333},
#  {'rating': 3.0, 'prediction': 3.801418439716312},
#  {'rating': 4.0, 'prediction': 4.25},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.567164179104478},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.57},
#  {'rating': 5.0, 'prediction': 4.666666666666667},
#  {'rating': 4.0, 'prediction': 4.214285714285714},
#  {'rating': 5.0, 'prediction': 4.725},
#  {'rating': 5.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.586705202312139},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.533333333333333},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 4.0, 'prediction': 4.3},
#  {'rating': 5.0, 'prediction': 4.072727272727272},
#  {'rating': 4.0, 'prediction': 4.555555555555555},
#  {'rating': 4.0, 'prediction': 4.428571428571429},
#  {'rating': 4.0, 'prediction': 4.521739130434782},
#  {'rating': 4.0, 'prediction': 4.818181818181818},
#  {'rating': 5.0, 'prediction': 3.8016528925619837},
#  {'rating': 5.0, 'prediction': 4.709090909090909},
#  {'rating': 5.0, 'prediction': 4.387096774193548},
#  {'rating': 5.0, 'prediction': 4.416666666666667},
#  {'rating': 5.0, 'prediction': 4.614406779661017},
#  {'rating': 5.0, 'prediction': 4.264705882352941},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 2.0, 'prediction': 2.4545454545454546},
#  {'rating': 5.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.614406779661017},
#  {'rating': 5.0, 'prediction': 4.2846715328467155},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.461538461538462},
#  {'rating': 4.0, 'prediction': 4.435185185185185},
#  {'rating': 5.0, 'prediction': 4.111111111111111},
#  {'rating': 5.0, 'prediction': 4.415584415584416},
#  {'rating': 5.0, 'prediction': 4.6},
#  {'rating': 5.0, 'prediction': 4.846153846153846},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 3.0, 'prediction': 4.013333333333334},
#  {'rating': 5.0, 'prediction': 4.283018867924528},
#  {'rating': 3.0, 'prediction': 3.5555555555555554},
#  {'rating': 4.0, 'prediction': 3.825925925925926},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 2.0, 'prediction': 2.0},
#  {'rating': 3.0, 'prediction': 3.0},
#  {'rating': 5.0, 'prediction': 4.0476190476190474},
#  {'rating': 5.0, 'prediction': 4.375},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.299703264094956},
#  {'rating': 5.0, 'prediction': 4.642857142857143},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 3.5},
#  {'rating': 4.0, 'prediction': 4.583333333333333},
#  {'rating': 5.0, 'prediction': 4.0675675675675675},
#  {'rating': 4.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.1},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.5},
#  {'rating': 5.0, 'prediction': 4.512820512820513},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.283018867924528},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.487719298245614},
#  {'rating': 5.0, 'prediction': 4.552173913043478},
#  {'rating': 1.0, 'prediction': 4.2},
#  {'rating': 5.0, 'prediction': 4.487719298245614},
#  {'rating': 4.0, 'prediction': 4.75},
#  {'rating': 5.0, 'prediction': 4.237704918032787},
#  {'rating': 5.0, 'prediction': 4.142857142857143},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.8},
#  {'rating': 4.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 4.315789473684211},
#  {'rating': 2.0, 'prediction': 4.7384615384615385},
#  {'rating': 5.0, 'prediction': 3.8666666666666667},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.403381642512077},
#  {'rating': 5.0, 'prediction': 4.833333333333333},
#  {'rating': 5.0, 'prediction': 4.5},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.25},
#  {'rating': 5.0, 'prediction': 4.8},
#  {'rating': 4.0, 'prediction': 4.714285714285714},
#  {'rating': 5.0, 'prediction': 4.4},
#  {'rating': 5.0, 'prediction': 4.571428571428571},
#  {'rating': 5.0, 'prediction': 4.2303030303030305},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 4.0, 'prediction': 4.666666666666667},
#  {'rating': 5.0, 'prediction': 3.75},
#  {'rating': 5.0, 'prediction': 4.7},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.6666666666666665},
#  {'rating': 5.0, 'prediction': 3.8666666666666667},
#  {'rating': 4.0, 'prediction': 4.5},
#  {'rating': 4.0, 'prediction': 4.2303030303030305},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.285714285714286},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 4.428571428571429},
#  {'rating': 3.0, 'prediction': 3.5},
#  {'rating': 5.0, 'prediction': 4.25},
#  {'rating': 4.0, 'prediction': 4.8},
#  {'rating': 5.0, 'prediction': 4.517241379310345},
#  {'rating': 4.0, 'prediction': 4.363636363636363},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 3.769230769230769},
#  {'rating': 4.0, 'prediction': 4.454545454545454},
#  {'rating': 5.0, 'prediction': 4.62962962962963},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.105263157894737},
#  {'rating': 1.0, 'prediction': 4.37948717948718},
#  {'rating': 5.0, 'prediction': 4.181818181818182},
#  {'rating': 5.0, 'prediction': 4.271317829457364},
#  {'rating': 5.0, 'prediction': 4.333333333333333},
#  {'rating': 5.0, 'prediction': 5.0},
#  {'rating': 5.0, 'prediction': 4.741935483870968},
#  ...]

# %% [markdown]
# 3\.1 Создайте два списка `A_list` и `F_list` на основе файла `rating_predictions.json`. Напишите функцию `mape_lists` без использования векторизованных операций и методов массивов `numpy` и без использования `numba` (проитерируйтесь по спискам и вычислите суммарное значение MAPE для всех элементов, а потом усредните результат).
#
# Измерьте время выполнения данной функции на входных данных `A_list` и `F_list`. Временем, затрачиваемым на создание списков, можно пренебречь.

# %%
A_list = []
F_list = []
for i in f:
  A_list.append(i['rating'])
  F_list.append(i['prediction'])

# %%
def mape_lists(A_list, F_list):
    s = 0
    for i in range(len(A_list)):
        s += abs((A_list[i] - F_list[i])/A_list[i])
    return 100/len(A_list) * s

# %%
mape_lists(A_list, F_list)
# Out:
# 13.325265503992638

# %%
# %time mape_lists(A_list, F_list)
# Out:
# CPU times: user 29.8 ms, sys: 0 ns, total: 29.8 ms
# Wall time: 30.4 ms
# 13.325265503992638

# %% [markdown]
# 3\.2. Создайте массивы `numpy` `A_array` и `F_array` на основе списков `A_list` и `F_list`. Напишите функцию `mape_numpy` с использованием векторизованных операций и методов массивов `numpy`.
#
# Измерьте время выполнения данной функции на входных данных `A_array` и `F_array`. Временем, затрачиваемым на создание массивов, можно пренебречь.

# %%
A_array = np.array(A_list)
F_array = np.array(F_list)

# %%
A_array
# Out:
# array([5., 5., 5., ..., 5., 5., 5.])

# %%
F_array
# Out:
# array([4.94444444, 4.4375    , 4.72727273, ..., 5.        , 4.14285714,
#        5.        ])

# %%
def mape_numpy(A_array, F_array):
    return 100/len(A_array) * (abs((A_array - F_array) / A_array)).sum()

# %%
# %timeit mape_numpy(A_array, F_array)
# Out:
# 533 µs ± 13.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# 3\.3. Создайте объекты `numba.typed.List` `A_typed` и `F_typed` на основе списков `A_list` и `F_list`. Напишите функцию `mape_numba` без использования векторизованных операций и методов массивов `numpy`, но с использованием `numba`.
#
# Измерьте время выполнения данной функции на входных данных `A_typed` и `F_typed`. Временем, затрачиваемым на создание объектов `numba.typed.List`, можно пренебречь.
#
# Измерьте время выполнения данной функции на входных данных `A_array` и `F_array`.

# %%
A_typed = numba.typed.List(A_list)
F_typed = numba.typed.List(F_list)

# %%
@njit
def mape_numba(A_typed, F_typed):
    s = 0
    for i in range(len(A_typed)):
        s += abs((A_typed[i]-F_typed[i])/A_typed[i])
    return 100/len(A_typed) * s

# %%
# %time mape_numba(A_typed, F_typed)
# Out:
# CPU times: user 327 ms, sys: 1.88 ms, total: 329 ms
# Wall time: 332 ms
# 13.325265503992638

# %%
# %time mape_numba(A_array, F_array)
# Out:
# CPU times: user 131 ms, sys: 0 ns, total: 131 ms
# Wall time: 136 ms
# 13.325265503992638

# %% [markdown]
# ## Векторизация

# %% [markdown]
# Сайт-агрегатор устроил акцию: он дарит купоны на посещение ресторана тем пользователям, оставившим отзывы, идентификатор которых является _красивым числом_. Натуральное число называется _красивым_, если первая цифра числа совпадает с последней цифрой числа.

# %% [markdown]
# 4\.1 Напишите функцию `is_pretty`, которая для каждого идентификатора пользователя из файла определяет, получит ли он подарок. Запрещается преобразовывать идентификатор пользователя к строке. Подтвердите корректность реализации, продемонстрировав примеры.

# %%
ids = reviews["recipe_id"].values

# %%
def is_pretty(n):
    F = n
    while F//10 != 0:
        F //= 10
    return n%10 == F

# %%
is_pretty(69)
# Out:
# False

# %%
is_pretty(121)
# Out:
# True

# %% [markdown]
# 4\.2 Посчитайте с помощью функции `is_pretty` количество пользователей, которые получат подарок. Выведите это количество на экран. Измерьте время расчетов для входных данных `ids`.

# %%
res4_2 = list(map(is_pretty, ids))
sum(res4_2)
# Out:
# 11955

# %%
# %time res4_2 =list(map(is_pretty, ids))
# Out:
# CPU times: user 432 ms, sys: 0 ns, total: 432 ms
# Wall time: 469 ms

# %% [markdown]
# 4\.3. При помощи `numpy` создайте векторизованную версию функции `is_pretty`. Посчитайте с помощью этой векторизованной функции количество пользователей, которые получат подарок. Выведите это количество на экран. Измерьте время расчетов для входных данных `ids`.

# %%
def is_pretty4_3(arr):
    last = arr % 10
    first = ids // 10**np.vectorize(int)(np.log10(ids))
    return last==first

# %%
is_pretty4_3(ids).sum()
# Out:
# 11955

# %%
# %%timeit
is_pretty4_3(ids).sum()
# Out:
# 16 ms ± 144 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# 4\.4. При помощи `numba` создайте векторизованную версию функции `is_pretty`. Посчитайте с помощью этой векторизованной функции количество пользователей, которые получат подарок. Выведите это количество на экран. Измерьте время расчетов для входных данных `ids`.
